# %% [markdown]
# # Return the One-Ip Table and devices path result
# During current use case, the final goals are present the One-Ip Table of devices in current domain and path result between two random devices in current domain.
# There are totally 10 REST APIs we going to concerned to be a part of this use case, as shown in following:<br>
#
# > 1) login API ([Step 1](#Step-1:-Calling-Login-API))<br>
# > 2) get_all_accessible_tenants API ([Step 2](#Step-2:-Calling-Get-All-Accessible-Tenants-API-with-authentication-token))<br>
# > 3) get_all_accessible_domains API ([Step 3](#Step-3:-Calling-Get-All-Accessible-Domains-API-with-token-and-tenantId))<br>
# > 4) specify_a_working_domain API ([Step 4](#Step-4:-Calling-Specify-A-Working-Domain-API))<br>
# > 5) get_all_devices API ([Step 5](#Step-5:-Calling-Get-All-Devices-API))<br>
# > 6) get_one_ip_table API ([Step 6](#Step-6:-Calling-Get-One-Ip-Table))<br>
# > 7) resolve_device_gateway API ([Step 7](#Step-7:-Calling-Resolve-Device-Gateway-API))<br>
# > 8) calculate_path API ([Step 8](#Step-8:-Calling-Calculate-Path-API))<br>
# > 9) get_patth_result API ([Step 9](#Step-9:-Calling-Get-Path-Calulation-Result-API))<br>
# > 10) logout API ([Step 10](#Step-10:-Calling-Logout-API))

# %% [markdown]
# The sequencial of provided APIs is also the sequence of our workflow steps.<br>
#
# ***Note:*** if users want to find the path results of devices, then the step sequence must be followed from number 7) to 9). If users call these APIs with a different sequential then there would be no results or some errors would be occured.

# %% [markdown]
# ## Step 0: import the corresponding modules in python and some fixed input parameters
# ***Note:*** If users try to use this code. please remember to change the "nb_url" to users' own working url.

# %%
# import python modules 
import requests
import time
import urllib3
import pprint
#urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
import json

nb_url = "http://192.168.28.79"
headers = {'Content-Type': 'application/json', 'Accept': 'application/json'}

# %% [markdown]
# ## Step 1: Calling Login API
# In step 1, we calling the login API with "username" and "password" as inputs. As response we can get the authentication token as one fixed input in following APIs calling. If users get errors when calling this API please check the API documentation on [Github_login](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_TEST1_LOGIN_API.ipynb)

# %%
username = "gdluserTest"
password = "123456"

body = {
    "username" : username,      
    "password" : password  
}

login_URL = nb_url + "/ServicesAPI/API/V1/Session"

def login(login_URL, body, headers):
    try:
        # Do the HTTP request
        response = requests.post(login_URL, headers=headers, data = json.dumps(body), verify=False)
        # Check for HTTP codes other than 200
        if response.status_code == 200:
            # Decode the JSON response into a dictionary and use the data
            js = response.json()
            return (js["token"])
        else:
            return ("Get token failed! - " + str(response.text))
    except Exception as e:
        return (str(e))
    
token = login(login_URL, body, headers)
print(token) # print out the authentication token.
# Out:
# cc25cbea-d244-494d-b6f9-32937bdadc69

# %% [markdown]
# ## Step 2: Calling Get All Accessible Tenants API with authentication token
# After we got the token from step 1, we need to use this token as a key to find all tenants which we have the access authentication. During this step, the most important feature is to get the tenant id of the corresponding tenant which we decide to work inside. After running this API successfully, we will get the tenantId of the willing tenant which will be set as another input for next step API calling. If users want to get more details about this API or get errors when calling this API please check the API documentation on [Github_tenant](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_TEST1_Get_All_Asseccible_Tenants_API_Test1%20.ipynb)

# %%
Accessible_tenants_url = nb_url + "/ServicesAPI/API/V1/CMDB/Tenants"

def get_all_accessible_tenants(Accessible_tenants_url, token, headers):
    headers["Token"] = token
    try:
        # Do the HTTP request
        response = requests.get(Accessible_tenants_url, headers=headers, verify=False)
        # Check for HTTP codes other than 200
        if response.status_code == 200:
            # Decode the JSON response into a dictionary and use the data
            result = response.json()
            tenants = result["tenants"]
            tenant =  [x for x in tenants if x["tenantName"] == "Initial Tenant"] # Name of the tenant which we are going to work inside
            #tj = tenant.json()
            tenantId = tenant[0]["tenantId"]
            #ten_j = json.dumps(tenant)
            return tenantId
        else:
            return ("Get tenants failed! - " + str(response.text))
    except Exception as e: return (e)

tenantId = get_all_accessible_tenants(Accessible_tenants_url, token, headers)
print(tenantId) # print out the specified tenant id.
# Out:
# fb24f3f0-81a7-1929-4b8f-99106c23fa5b

# %% [markdown]
# ## Step 3: Calling Get All Accessible Domains API with token and tenantId
# In step 3, we are going to find all accessible domains in the corressponding tenant which we have got the tenantId from previous step. Similar with step 2, during current API call, we have to decide which domain we are going to work inside and get the domainId at meanwhile to prepare for next API calling. If users get errors when calling this API please check the API documentation on [Github_domain](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_Get_all_accessible_domains_of_a_tenant%20_Test1%20.ipynb)

# %%
Accessible_domains_url = nb_url + "/ServicesAPI/API/V1/CMDB/Domains"

def get_all_accessible_domains(tenantId, token, headers):
    headers["Token"] = token
    data = {"tenantId": tenantId}
    try:
        # Do the HTTP request
        response = requests.get(Accessible_domains_url, params=data, headers=headers, verify=False)
        # Check for HTTP codes other than 200
        if response.status_code == 200:
            # Decode the JSON response into a dictionary and use the data
            result = response.json()
            domains = result["domains"]
            domain =  [x for x in domains if x["domainName"] == "Support and Service"]# Name of the domain which we are going to work inside
            domainId = domain[0]["domainId"]
            return domainId
        else:
            return ("Get domains failed! - " + str(response.text))

    except Exception as e: print (str(e))

domainId = get_all_accessible_domains(tenantId, token, headers)
print(domainId) # Print out the specified domain Id.
# Out:
# 850ff5e9-c639-404d-85a3-d920dbee509c

# %% [markdown]
# ## Step 4: Calling Specify A Working Domain API
# After we running this step successfully, we finally complete the full login processes which means we totally join in Netbrain System by calling APIs. Next step, we will start to use Netbrain functions formally. If users get errors when calling this API please check the API documentation on [Github_domain](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_Specify_a_domain_to_work_on_API_Test1%20.ipynb)
#
# ***Note:*** Users mush complete first four steps to totally join in Netbrain system everytime after logout. If users can remember their tenantId and domainId, users can only complete Step 1 then jump to Step 4 to input the tenantId and domainId directly.

# %%
Specify_a_working_domain_url = nb_url + "/ServicesAPI/API/V1/Session/CurrentDomain"

def specify_a_working_domain(tenantId, domainId, Specify_a_working_domain_url, headers, token):
    headers["Token"] = token
    body = {
        "tenantId": tenantId,
        "domainId": domainId
    }
    
    try:
        # Do the HTTP request
        response = requests.put(Specify_a_working_domain_url, data=json.dumps(body), headers=headers, verify=False)
        # Check for HTTP codes other than 200
        if response.status_code == 200:
            # Decode the JSON response into a dictionary and use the data
            result = response.json()
            return ("Working Domain Specified Successfully, with domainId: " + domainId)
            
        elif response.status_code != 200:
            return ("Login failed! - " + str(response.text))

    except Exception as e: print (str(e))

res =  specify_a_working_domain(tenantId, domainId, Specify_a_working_domain_url, headers, token)
print (res)
# Out:
# Working Domain Specified Successfully, with domainId: 850ff5e9-c639-404d-85a3-d920dbee509c

# %% [markdown]
# ## Step 5: Calling Get All Devices API
# As we have mention at deginning, in this use case, we are going to get One-Ip table and path result. So the precondition is the information of devices. In current step, after we calling this Api successfully, we will get information of all devices in current domain. As following, i provide a sub-step, because after calling get all devices API we will get a json file from API response, it 's include device id, device management ip, device hostname and some other information. But we only need the managment Ip as input for next step. Thus, we provide a small funtion to filt out the "mgmIp" from step5 json file.
# If users get errors when calling this API please check the API documentation on [Github_devices](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Device%20API%20Design/STANDARD_formate_Get_Devices_API_Test.ipynb)

# %%
Get_all_devices_in_domain_url = nb_url + "/ServicesAPI/API/V1/CMDB/Devices"

def get_all_devices(Get_all_devices_in_domain_url, headers, token):
    try:
        response = requests.get(Get_all_devices_in_domain_url, headers=headers, verify=False)
        if response.status_code == 200:
            result = response.json()
            devices = result["devices"]
            return devices
        else:
            return("Get Devices failed! - " + str(response.text))
    except Exception as e:
        return (str(e)) 
    
devices = get_all_devices(Get_all_devices_in_domain_url, headers, token)

print("Total Devices Number: " + str(len(devices)))

devices
# Out:
# Total Devices Number: 93
# [{'id': '1266a178-b829-43c8-9c24-c34154a15d30',
#   'mgmtIP': '192.168.28.204',
#   'hostname': 'R20',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '497b25bd-1f8c-4bfa-80be-49ab692ce4d4',
#   'mgmtIP': '123.10.1.10',
#   'hostname': 'R3',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'f190b385-676f-4579-ad6d-700122a21caf',
#   'mgmtIP': '123.10.1.17',
#   'hostname': 'R2',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '1d48d218-06cf-4657-af2c-39796946122b',
#   'mgmtIP': '123.10.1.1',
#   'hostname': 'R4',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '81229708-571a-419a-a10d-9481661718a4',
#   'mgmtIP': '123.10.1.2',
#   'hostname': 'R1',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '6d62e420-af59-4ee3-948d-54df60fe05ca',
#   'mgmtIP': '123.10.1.6',
#   'hostname': 'R5',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '5c3d72d6-d0f2-41f4-8b1e-5762dff6e55a',
#   'mgmtIP': '123.10.1.22',
#   'hostname': 'R6',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'b98f107a-622e-4985-8f95-f5b541f699f3',
#   'mgmtIP': '123.7.7.7',
#   'hostname': 'R7',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '9b60fcfc-a405-478d-83a3-99b0ce6c9b64',
#   'mgmtIP': '123.8.8.8',
#   'hostname': 'R8',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '087814b3-f372-4878-bdcd-c31ba061c864',
#   'mgmtIP': '123.10.10.10',
#   'hostname': 'R10',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'f7b8059c-61c1-4adc-9879-f1d726a68a49',
#   'mgmtIP': '123.11.11.11',
#   'hostname': 'R11',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '15b689cb-25a1-4f8f-bb34-7a0909dcbbda',
#   'mgmtIP': '123.9.9.9',
#   'hostname': 'R9',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '9717d31d-f046-41ea-8b73-439d7f0f9c80',
#   'mgmtIP': '123.203.3.3',
#   'hostname': 'SW3',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '05b96a11-ee38-4f2d-9a77-76452e3b366c',
#   'mgmtIP': '123.204.4.4',
#   'hostname': 'SW4',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'a87174e0-be82-46ac-8498-ff81e23a6bca',
#   'mgmtIP': '123.15.15.15',
#   'hostname': 'R15',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'f07c93b0-9b0f-4ebe-94e8-53af58759aa6',
#   'mgmtIP': '123.20.1.11',
#   'hostname': 'SW6',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '11c410f5-223f-412b-a955-6b63f2a3b356',
#   'mgmtIP': '123.20.1.3',
#   'hostname': 'SW5',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '6b4dc692-bcd7-459e-bdc3-10145945800f',
#   'mgmtIP': '123.20.1.10',
#   'hostname': 'R17',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '87217bc5-0417-4c1e-b892-0d4eb350687a',
#   'mgmtIP': '123.20.1.2',
#   'hostname': 'R16',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '71e07730-1247-4f5f-acbc-2b3428f8d0cf',
#   'mgmtIP': '10.18.19.18',
#   'hostname': 'R18',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '81d7beaf-50d7-41c4-bba1-256198442db9',
#   'mgmtIP': '123.12.12.12',
#   'hostname': 'R12',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'a5d9b1d2-fc38-403a-9a32-c69ebca27a47',
#   'mgmtIP': '10.1.12.2',
#   'hostname': 'Client1',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'af39aa9a-f46d-432d-8f16-41f0a3a2934d',
#   'mgmtIP': '123.13.13.13',
#   'hostname': 'R13',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '7b9e10b8-ba4e-4f6f-8a0d-a1403f7c47b3',
#   'mgmtIP': '10.1.13.2',
#   'hostname': 'Client2',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'fb8aaa54-6ca6-4766-ad07-07955d6ff73f',
#   'mgmtIP': '123.14.14.14',
#   'hostname': 'R14',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '7a172c80-bc3f-4e2a-ad53-45a7b22ffcc5',
#   'mgmtIP': '10.1.14.2',
#   'hostname': 'Client3',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'a8652884-7701-5e84-b4d8-cc03652490e5',
#   'mgmtIP': '',
#   'hostname': 'ISP',
#   'deviceTypeName': 'MPLS Cloud',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'c158cf17-146e-9fb5-f5a7-128ecd442d12',
#   'mgmtIP': '',
#   'hostname': 'AS30000',
#   'deviceTypeName': 'MPLS Cloud',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'e23ac06d-9be9-b5e3-39b5-5242804d1f3f',
#   'mgmtIP': '',
#   'hostname': 'AS20003',
#   'deviceTypeName': 'MPLS Cloud',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '328fc0af-9532-ab41-bb23-416335ce665a',
#   'mgmtIP': '',
#   'hostname': 'AS20002',
#   'deviceTypeName': 'MPLS Cloud',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '6ed030e8-de68-4216-ec4d-3a90484e28ca',
#   'mgmtIP': '',
#   'hostname': 'AS20001',
#   'deviceTypeName': 'MPLS Cloud',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '2a2992e9-0b34-43fb-ae7c-feb3110743d8',
#   'mgmtIP': '10.54.221.66',
#   'hostname': 'R01FOB011',
#   'deviceTypeName': 'Alcatel OmniSwitch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '6d6308de-e550-4e21-b2a5-d416c1be54f7',
#   'mgmtIP': '172.21.31.254',
#   'hostname': 'acr07jcsntn',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'cebf23e2-c096-4c9a-b1b7-5f242756a10f',
#   'mgmtIP': '172.21.28.33',
#   'hostname': 'acr09jcsntn',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'cb305a98-a917-444b-90ef-fbdf75b54790',
#   'mgmtIP': '172.31.224.21',
#   'hostname': 'bbr02euclwi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '2d177cd6-62a7-408d-b944-68ea4d3af5cf',
#   'mgmtIP': '172.31.83.7',
#   'hostname': 'crr01jcsntn',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '6067b685-c96e-46a7-bdb1-d33ccb302121',
#   'mgmtIP': '172.31.224.18',
#   'hostname': 'sar04euclwi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'a404109e-8140-4150-9e0c-defbac1b3a3a',
#   'mgmtIP': '123.19.19.19',
#   'hostname': 'R19',
#   'deviceTypeName': 'Cisco Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '4b1dc109-ed2e-4c22-9886-f8b6c183db60',
#   'mgmtIP': '10.108.64.254',
#   'hostname': '3XSQ-COREWAN-PE2',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '81028200-9411-47fc-9c4d-2b7f857bf3f6',
#   'mgmtIP': '10.108.64.29',
#   'hostname': 'CME-COREWAN-PE4',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'f67c326c-4db7-4efb-8156-f677fd3417d7',
#   'mgmtIP': '10.108.80.19',
#   'hostname': 'DTC-COREWAN-PE2',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '90c01e79-a878-4a20-b65a-4ec136f74c16',
#   'mgmtIP': '10.108.64.23',
#   'hostname': 'EGE-COREWAN-PE4',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'fbfc1d11-b02f-4e50-8414-f5ed3e0a2232',
#   'mgmtIP': '10.108.64.41',
#   'hostname': 'HDC-COREWAN-PE6',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'fce947ef-2590-4ce5-b1bf-0bbc15c05ce9',
#   'mgmtIP': '10.108.64.27',
#   'hostname': 'NJH-COREWAN-PE2',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '49c7475d-0011-4104-8fc2-b8629f3ae201',
#   'mgmtIP': '10.108.64.17',
#   'hostname': 'NTC-COREWAN-PE2',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'f79f733b-5583-44f8-ab29-ce181abf380c',
#   'mgmtIP': '10.108.64.33',
#   'hostname': 'NY8-COREWAN-PE2',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'afe3af0c-a17e-44da-9b94-a99722d18835',
#   'mgmtIP': '10.108.64.48',
#   'hostname': 'OCB-COREWAN-PE4',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'd0abc77f-fd90-40c3-83da-56ce66542f5d',
#   'mgmtIP': '162.8.250.239',
#   'hostname': 'OCD-COREWAN-PE4',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '1132187c-1faf-4a5c-8cd2-cc8e152d2cba',
#   'mgmtIP': '10.108.88.30',
#   'hostname': 'PLN-COREWAN-PE2',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '520bdba2-55fd-4b84-b9d6-50e2e1c54a77',
#   'mgmtIP': '10.108.80.41',
#   'hostname': 'TN2-COREWAN-PE2',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '8f5144ad-6579-448f-b6fe-1f2cc146ada1',
#   'mgmtIP': '172.31.224.70',
#   'hostname': 'bar01cntlco',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '7a793022-d7db-4418-acb3-348c936647d2',
#   'mgmtIP': '172.31.224.110',
#   'hostname': 'bbr01aldlmi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '7b1ad1cf-ada4-4da9-82e1-91b0c2eff528',
#   'mgmtIP': '96.34.192.120',
#   'hostname': 'bbr01chcgil',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '5b764f00-347e-4f7b-8437-b75a33bdff90',
#   'mgmtIP': '172.31.224.130',
#   'hostname': 'bbr01dnvrco',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'bcd88c97-a822-428f-8da8-80c5344d5486',
#   'mgmtIP': '172.31.224.40',
#   'hostname': 'bbr01olvemo',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '3636842f-f75e-4233-bf6b-c998078d68e2',
#   'mgmtIP': '172.31.224.100',
#   'hostname': 'bbr01oxfrma',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'acfd938c-cddc-49f1-9396-a7f4e7f06b25',
#   'mgmtIP': '172.31.224.111',
#   'hostname': 'bbr01sgnwmi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '63e14498-13db-4496-a36e-0b1493e6b762',
#   'mgmtIP': '172.31.224.121',
#   'hostname': 'bbr02chcgil',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'aac32025-1d1e-4ef1-8acb-9a6560153b65',
#   'mgmtIP': '172.31.75.8',
#   'hostname': 'crr02oxfrma',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '823fc1e4-1bbf-4f0e-a59c-2895401edc0a',
#   'mgmtIP': '172.31.64.66',
#   'hostname': 'sar02bodcma',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '3db77431-e324-466d-947e-4c688405a272',
#   'mgmtIP': '172.31.224.20',
#   'hostname': 'bbr01euclwi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '7b89cb90-726e-47fd-9184-946fc62ccd7e',
#   'mgmtIP': '172.31.224.131',
#   'hostname': 'bbr02dnvrco',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '118956d4-4b4a-4ed6-b174-ee70f1340b4a',
#   'mgmtIP': '172.31.40.72',
#   'hostname': 'crr01euclwi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'f6a15341-122c-4703-8276-428f49542557',
#   'mgmtIP': '172.31.40.76',
#   'hostname': 'crr01ftbgwi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'c41b2045-c5e6-425b-acd7-96d0b2138173',
#   'mgmtIP': '172.31.40.7',
#   'hostname': 'crr01onlswi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '60cc97db-3c52-447c-85a6-e8a98e3d125f',
#   'mgmtIP': '172.31.40.36',
#   'hostname': 'dtr01euclwi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'e6c5fb43-3e43-4282-bc8e-2b4689a18416',
#   'mgmtIP': '172.31.37.4',
#   'hostname': 'dtr03jnvlwi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '1be9a32a-cbab-40b5-86f5-c573649f956e',
#   'mgmtIP': '172.18.27.1',
#   'hostname': 'nxs01euclwi',
#   'deviceTypeName': 'Cisco Nexus Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'ec6a1e81-0581-413a-89e3-079749b7dea4',
#   'mgmtIP': '172.31.181.25',
#   'hostname': 'acr01csbyor',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '489529b4-5531-446e-9d49-bad190d21fd5',
#   'mgmtIP': '172.31.181.26',
#   'hostname': 'acr01rsbgor',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '1375f8ec-d9eb-49c2-81b4-e50dc8946bc7',
#   'mgmtIP': '172.27.146.241',
#   'hostname': 'acr02lnbhca',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '15980baf-01ff-4954-92d5-66e2e022342f',
#   'mgmtIP': '172.31.176.222',
#   'hostname': 'crr01mtpkca',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '88b64f0a-6d79-48ce-953b-c88b3a8e5941',
#   'mgmtIP': '172.31.176.223',
#   'hostname': 'crr02mtpkca',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '248daea8-3663-415e-82e4-c00fc65a0906',
#   'mgmtIP': '172.31.181.34',
#   'hostname': 'dtr01csbyor',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '550c541d-9be6-46e1-8c26-5c9297f2f84b',
#   'mgmtIP': '172.31.176.18',
#   'hostname': 'dtr01lnbhca',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'd3d85682-42bc-4081-a80d-40b85bbfaf92',
#   'mgmtIP': '172.31.181.21',
#   'hostname': 'dtr01rsbgor',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'e907f6cc-e0e1-4460-9777-9733f0b8cc44',
#   'mgmtIP': '172.31.176.19',
#   'hostname': 'dtr02lnbhca',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'bf255bca-2efd-41cc-b40f-d5be617db3e1',
#   'mgmtIP': '172.31.176.13',
#   'hostname': 'dtr03mtpkca',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'b7cee44a-40cf-41a4-a839-19e81fe82a86',
#   'mgmtIP': '172.31.224.32',
#   'hostname': 'prr01lsanca',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '1ba66516-a4e6-49e3-9d67-5cd111334e31',
#   'mgmtIP': '172.31.224.140',
#   'hostname': 'bbr01gdisne',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '976a4556-bc5c-43c1-817f-f3abbbcbc754',
#   'mgmtIP': '172.31.198.173',
#   'hostname': 'crr01gdisne',
#   'deviceTypeName': 'Juniper Router',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '6667fb4b-6122-4408-91ba-50e17e8ac9bf',
#   'mgmtIP': '172.31.198.152',
#   'hostname': 'dtr01krnyne',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': 'c5beb030-93f6-4716-a28a-cad5841421ca',
#   'mgmtIP': '172.31.198.133',
#   'hostname': 'sar01krnyne',
#   'deviceTypeName': 'Cisco Nexus Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '8cd4ffc4-4219-48a3-b6ed-7911b76009e8',
#   'mgmtIP': '172.31.224.17',
#   'hostname': 'sar03euclwi',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '36b0deff-f671-44cb-9374-063802345200',
#   'mgmtIP': '66.109.2.255',
#   'hostname': 'ATLNGAMQ46W-BCR00',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '8dbff27d-71ac-4d9c-b095-7dc02710407f',
#   'mgmtIP': '71.66.63.30',
#   'hostname': 'chrc1-h01-h01-video-4500-2',
#   'deviceTypeName': 'Cisco IOS Switch',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '2104544b-9d2e-4ab1-bd89-a1c717931044',
#   'mgmtIP': '71.66.60.54',
#   'hostname': 'chrcnctr01-rtr04',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '9a190ef5-baed-4e88-b000-222468deb070',
#   'mgmtIP': '66.109.2.97',
#   'hostname': 'CHRCNCTR04H-BAR03',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '4f5a1fc3-27cb-4d8c-b4e3-f93e58004ba7',
#   'mgmtIP': '66.109.2.250',
#   'hostname': 'DLLSTX976IW-BCR00',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '687a2385-dd6c-44ad-aa23-47c1821f9547',
#   'mgmtIP': '66.109.2.99',
#   'hostname': 'ENWDCOCD0AW-BAR03',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '4745c233-84e9-482b-aaab-d417b57f39ec',
#   'mgmtIP': '66.109.2.249',
#   'hostname': 'HSTQTX0209W-BCR00',
#   'deviceTypeName': 'Cisco IOS XR',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '720f9aa1-9181-4a89-b92c-8d7f30848d90',
#   'mgmtIP': '10.104.130.84',
#   'hostname': 'aa-dev-lb-rhp-1',
#   'deviceTypeName': 'F5 Load Balancer',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'},
#  {'id': '21e31930-edda-4e00-9465-c12216b9cad0',
#   'mgmtIP': '10.104.130.85',
#   'hostname': 'aa-dev-lb-rhp-2',
#   'deviceTypeName': 'F5 Load Balancer',
#   'firstDiscoverTime': '0001-01-01T00:00:00',
#   'lastDiscoverTime': '0001-01-01T00:00:00'}]

# %% [markdown]
# ### A sub-step of Step 5, to filt out the "mgmIp" from json file.

# %%
ips = []

for i in range(len(devices)):
    ip = devices[i]["mgmtIP"]
    if ip != "":
        ips.append(ip)
  
print(str(len(ips)))
ips
# Out:
# 88
# ['192.168.28.204',
#  '123.10.1.10',
#  '123.10.1.17',
#  '123.10.1.1',
#  '123.10.1.2',
#  '123.10.1.6',
#  '123.10.1.22',
#  '123.7.7.7',
#  '123.8.8.8',
#  '123.10.10.10',
#  '123.11.11.11',
#  '123.9.9.9',
#  '123.203.3.3',
#  '123.204.4.4',
#  '123.15.15.15',
#  '123.20.1.11',
#  '123.20.1.3',
#  '123.20.1.10',
#  '123.20.1.2',
#  '10.18.19.18',
#  '123.12.12.12',
#  '10.1.12.2',
#  '123.13.13.13',
#  '10.1.13.2',
#  '123.14.14.14',
#  '10.1.14.2',
#  '10.54.221.66',
#  '172.21.31.254',
#  '172.21.28.33',
#  '172.31.224.21',
#  '172.31.83.7',
#  '172.31.224.18',
#  '123.19.19.19',
#  '10.108.64.254',
#  '10.108.64.29',
#  '10.108.80.19',
#  '10.108.64.23',
#  '10.108.64.41',
#  '10.108.64.27',
#  '10.108.64.17',
#  '10.108.64.33',
#  '10.108.64.48',
#  '162.8.250.239',
#  '10.108.88.30',
#  '10.108.80.41',
#  '172.31.224.70',
#  '172.31.224.110',
#  '96.34.192.120',
#  '172.31.224.130',
#  '172.31.224.40',
#  '172.31.224.100',
#  '172.31.224.111',
#  '172.31.224.121',
#  '172.31.75.8',
#  '172.31.64.66',
#  '172.31.224.20',
#  '172.31.224.131',
#  '172.31.40.72',
#  '172.31.40.76',
#  '172.31.40.7',
#  '172.31.40.36',
#  '172.31.37.4',
#  '172.18.27.1',
#  '172.31.181.25',
#  '172.31.181.26',
#  '172.27.146.241',
#  '172.31.176.222',
#  '172.31.176.223',
#  '172.31.181.34',
#  '172.31.176.18',
#  '172.31.181.21',
#  '172.31.176.19',
#  '172.31.176.13',
#  '172.31.224.32',
#  '172.31.224.140',
#  '172.31.198.173',
#  '172.31.198.152',
#  '172.31.198.133',
#  '172.31.224.17',
#  '66.109.2.255',
#  '71.66.63.30',
#  '71.66.60.54',
#  '66.109.2.97',
#  '66.109.2.250',
#  '66.109.2.99',
#  '66.109.2.249',
#  '10.104.130.84',
#  '10.104.130.85']

# %% [markdown]
# ## Step 6: Calling Get One Ip Table
# After we got all devices management IP from step 5, we can calling the Get One-Ip table API. During this step, we totally call twice of corresponding API, first calling we loop all devices in current domian with full input parameters provided, second call we only provide the "beginIndex" and "count" parameters. If users want to get more details about this API or get errors when calling this API please check the API documentation on [Github_One-Ip_Table](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Overall%20Plan%EF%BC%88Northbound%20API%EF%BC%89/STANDARD_formate_GEt_One_Ip_Table_API_Test1%20.ipynb)

# %%
Get_One_Ip_Table_url = nb_url + "/ServicesAPI/API/V1/CMDB/Topology/OneIPTable"
results_with_Ip_Input = []
results = []

def get_one_ip_table(Get_One_Ip_Table_url, ip, beginIndex, count, headers, token):
    headers["Token"] = token
    data = {
        "ip" : ip,
        "beginIndex" : beginIndex,
        "count" : count
    }
    try:
        response = requests.get(Get_One_Ip_Table_url, params = data, headers = headers, verify = False)
        if response.status_code == 200:
            result = response.json()
            return (result)
        else:
            return ("Get One-Ip Table failed! - " + str(response.text))

    except Exception as e:
        return (str(e))  

# First Calling
for i in range(len(ips)):
    result = get_one_ip_table(Get_One_Ip_Table_url, ips[i], 0, 3, headers, token)
    #res = result["OneIPList"]
    results.append(result)

print(str(len(results)))
results
# Out:
# 88
# [{'OneIPList': [{'lanSegment': '192.168.28.0/22',
#     'ip': '192.168.28.204',
#     'mac': 'AABB.CC00.2210',
#     'devName': 'R20',
#     'interfaceName': 'Ethernet0/1',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'R20.Ethernet0/1',
#     'sourceDevice': 'R20',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:12Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.10.1.8/30',
#     'ip': '123.10.1.10',
#     'mac': 'AABB.CC00.0710',
#     'devName': 'R3',
#     'interfaceName': 'Ethernet0/1',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'R3.Ethernet0/1',
#     'sourceDevice': 'R3',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.10.1.16/30',
#     'ip': '123.10.1.17',
#     'mac': 'AABB.CC00.0620',
#     'devName': 'R2',
#     'interfaceName': 'Ethernet0/2',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'R2.Ethernet0/2',
#     'sourceDevice': 'R2',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.10.1.0/30',
#     'ip': '123.10.1.1',
#     'mac': 'AABB.CC00.0810',
#     'devName': 'R4',
#     'interfaceName': 'Ethernet0/1',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'R4.Ethernet0/1',
#     'sourceDevice': 'R4',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.10.1.0/30',
#     'ip': '123.10.1.2',
#     'mac': 'AABB.CC00.0520',
#     'devName': 'R1',
#     'interfaceName': 'Ethernet0/2',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'R1.Ethernet0/2',
#     'sourceDevice': 'R1',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.10.1.4/30',
#     'ip': '123.10.1.6',
#     'mac': 'AABB.CC00.0910',
#     'devName': 'R5',
#     'interfaceName': 'Ethernet0/1',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'R5.Ethernet0/1',
#     'sourceDevice': 'R5',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.10.1.20/30',
#     'ip': '123.10.1.22',
#     'mac': 'AABB.CC00.0A20',
#     'devName': 'R6',
#     'interfaceName': 'Ethernet0/2',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'R6.Ethernet0/2',
#     'sourceDevice': 'R6',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.20.1.8/29',
#     'ip': '123.20.1.11',
#     'mac': 'AABB.CC80.1300',
#     'devName': 'SW6',
#     'interfaceName': 'Vlan66',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'SW6.Vlan66',
#     'sourceDevice': 'SW6',
#     'serverType': 2001,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.20.1.0/29',
#     'ip': '123.20.1.3',
#     'mac': 'AABB.CC80.1000',
#     'devName': 'SW5',
#     'interfaceName': 'Vlan55',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'SW5.Vlan55',
#     'sourceDevice': 'SW5',
#     'serverType': 2001,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.20.1.8/29',
#     'ip': '123.20.1.10',
#     'mac': 'AABB.CC00.1410',
#     'devName': 'R17',
#     'interfaceName': 'Ethernet0/1',
#     'switchName': 'SW6',
#     'portName': 'Ethernet0/1',
#     'alias': '',
#     'dns': 'R17.Ethernet0/1',
#     'sourceDevice': 'R17',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '123.20.1.0/29',
#     'ip': '123.20.1.2',
#     'mac': 'AABB.CC00.1210',
#     'devName': 'R16',
#     'interfaceName': 'Ethernet0/1',
#     'switchName': 'SW5',
#     'portName': 'Ethernet0/1',
#     'alias': '',
#     'dns': 'R16.Ethernet0/1',
#     'sourceDevice': 'R16',
#     'serverType': 2,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '10.1.12.0/24',
#     'ip': '10.1.12.2',
#     'mac': 'AABB.CC00.2300',
#     'devName': 'Client1',
#     'interfaceName': 'Ethernet0/0',
#     'switchName': 'R12',
#     'portName': 'Ethernet0/0',
#     'alias': '',
#     'dns': 'Client1.Ethernet0/0',
#     'sourceDevice': 'Client1',
#     'serverType': 2,
#     'switchType': 2,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '10.1.13.0/24',
#     'ip': '10.1.13.2',
#     'mac': 'AABB.CC00.2400',
#     'devName': 'Client2',
#     'interfaceName': 'Ethernet0/0',
#     'switchName': 'R13',
#     'portName': 'Ethernet0/0',
#     'alias': '',
#     'dns': 'Client2.Ethernet0/0',
#     'sourceDevice': 'Client2',
#     'serverType': 2,
#     'switchType': 2,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '10.1.14.0/24',
#     'ip': '10.1.14.2',
#     'mac': 'AABB.CC00.2500',
#     'devName': 'Client3',
#     'interfaceName': 'Ethernet0/0',
#     'switchName': 'R14',
#     'portName': 'Ethernet0/0',
#     'alias': '',
#     'dns': 'Client3.Ethernet0/0',
#     'sourceDevice': 'Client3',
#     'serverType': 2,
#     'switchType': 2,
#     'updateTime': '2019-02-19T06:04:13Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '10.54.221.64/27',
#     'ip': '10.54.221.66',
#     'mac': 'E8E7.324C.14E0',
#     'devName': 'R01FOB011',
#     'interfaceName': 'int-vlan100',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'R01FOB011.int-vlan100',
#     'sourceDevice': 'R01FOB011',
#     'serverType': 10418,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:14Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': 'Alcatel-Lucent',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '172.21.31.248/29',
#     'ip': '172.21.31.254',
#     'mac': '001B.0DEC.1B00',
#     'devName': 'acr07jcsntn',
#     'interfaceName': 'Vlan160',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'acr07jcsntn.Vlan160',
#     'sourceDevice': 'acr07jcsntn',
#     'serverType': 2001,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:16Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': 'Cisco Systems',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '172.21.28.32/27',
#     'ip': '172.21.28.33',
#     'mac': '0015.FA3A.3580',
#     'devName': 'acr09jcsntn',
#     'interfaceName': 'Vlan7',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'acr09jcsntn.Vlan7',
#     'sourceDevice': 'acr09jcsntn',
#     'serverType': 2001,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:22Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': 'Cisco Systems',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '10.108.88.28/30',
#     'ip': '10.108.88.30',
#     'mac': 'FC99.4742.4E40',
#     'devName': 'PLN-COREWAN-PE2',
#     'interfaceName': 'TenGigabitEthernet1/1',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'PLN-COREWAN-PE2.TenGigabitEthernet1/1',
#     'sourceDevice': 'PLN-COREWAN-PE2',
#     'serverType': 2001,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:40Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '172.18.27.0/27',
#     'ip': '172.18.27.1',
#     'mac': '4055.3905.B9C1',
#     'devName': 'nxs01euclwi',
#     'interfaceName': 'Vlan800',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'nxs01euclwi.Vlan800',
#     'sourceDevice': 'nxs01euclwi',
#     'serverType': 2004,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:36Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': 'Cisco Systems',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '172.27.146.240/29',
#     'ip': '172.27.146.241',
#     'mac': '0027.0DCA.80C0',
#     'devName': 'acr02lnbhca',
#     'interfaceName': 'Vlan18',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'acr02lnbhca.Vlan18',
#     'sourceDevice': 'acr02lnbhca',
#     'serverType': 2001,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:41Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': 'Cisco Systems',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '71.66.60.54/31',
#     'ip': '71.66.60.54',
#     'mac': 'F872.EA48.9B0A',
#     'devName': 'chrcnctr01-rtr04',
#     'interfaceName': 'Bundle-Ether14',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'chrcnctr01-rtr04.Bundle-Ether14',
#     'sourceDevice': 'chrcnctr01-rtr04',
#     'serverType': 2999,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:43Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': '',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [], 'statusCode': 790200, 'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '10.104.130.0/24',
#     'ip': '10.104.130.84',
#     'mac': '000A.49B1.57C1',
#     'devName': 'aa-dev-lb-rhp-1',
#     'interfaceName': 'mgmt',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'aa-dev-lb-rhp-1.mgmt',
#     'sourceDevice': 'aa-dev-lb-rhp-1',
#     'serverType': 2003,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:44Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': 'F5 Networks, Inc.',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'},
#  {'OneIPList': [{'lanSegment': '10.104.130.0/24',
#     'ip': '10.104.130.85',
#     'mac': '000A.49B1.4A81',
#     'devName': 'aa-dev-lb-rhp-2',
#     'interfaceName': 'mgmt',
#     'switchName': '',
#     'portName': '',
#     'alias': '',
#     'dns': 'aa-dev-lb-rhp-2.mgmt',
#     'sourceDevice': 'aa-dev-lb-rhp-2',
#     'serverType': 2003,
#     'switchType': 2001,
#     'updateTime': '2019-02-19T06:04:44Z',
#     'userFlag': 9,
#     'source': 'Device Interface',
#     'vendor': 'F5 Networks, Inc.',
#     'descr': ''}],
#   'statusCode': 790200,
#   'statusDescription': 'Success.'}]

# %%
# Second calling
result = get_one_ip_table(Get_One_Ip_Table_url, "", 0, 3, headers, token)
temp1 = result["OneIPList"]
print(str(len(temp1)))
temp1
# Out:
# 3
# [{'lanSegment': '192.152.38.24/29',
#   'ip': '192.152.38.30',
#   'mac': '78BA.F929.DDA1',
#   'devName': 'DTC-COREWAN-PE2',
#   'interfaceName': 'Bundle-Ether5.678',
#   'switchName': '',
#   'portName': '',
#   'alias': '',
#   'dns': 'DTC-COREWAN-PE2.Bundle-Ether5.678',
#   'sourceDevice': 'DTC-COREWAN-PE2',
#   'serverType': 2999,
#   'switchType': 2001,
#   'updateTime': '2019-02-19T06:04:38Z',
#   'userFlag': 9,
#   'source': 'Device Interface',
#   'vendor': '',
#   'descr': ''},
#  {'lanSegment': '96.34.14.48/31',
#   'ip': '96.34.14.48',
#   'mac': '8CB6.4FE9.678A',
#   'devName': 'dtr01krnyne',
#   'interfaceName': 'Bundle-Ether53.10',
#   'switchName': '',
#   'portName': '',
#   'alias': '',
#   'dns': 'dtr01krnyne.Bundle-Ether53.10',
#   'sourceDevice': 'dtr01krnyne',
#   'serverType': 2999,
#   'switchType': 2001,
#   'updateTime': '2019-02-19T06:04:41Z',
#   'userFlag': 9,
#   'source': 'Device Interface',
#   'vendor': 'Cisco Systems',
#   'descr': ''},
#  {'lanSegment': '96.34.14.48/31',
#   'ip': '96.34.14.49',
#   'mac': 'D46D.5020.6B1D',
#   'devName': 'dtr01krnyne',
#   'interfaceName': 'TenGigE0/0/0/5',
#   'switchName': '',
#   'portName': '',
#   'alias': '',
#   'dns': 'dtr01krnyne.TenGigE0/0/0/5',
#   'sourceDevice': 'dtr01krnyne',
#   'serverType': 2999,
#   'switchType': 2001,
#   'updateTime': '2019-02-19T06:04:41Z',
#   'userFlag': 9,
#   'source': 'Device Interface',
#   'vendor': '',
#   'descr': ''}]

# %% [markdown]
# ## Step 7: Calling Resolve Device Gateway API
# Our second goal of this use case is to get the path result of random devices in current domain. Now we start from resolve devices gateway API. Mention again, if users want to get path result by calling APIs then users must follow the sequencial of step 7 to step 9. In step 7, we will input the Ip list we have got from step 5. After the API running successfully, we will get a gateway list with some device informations which is the required input for next step. If users want to get more details about this API or get errors when calling this API please check the API documentation on [Github_Gateway](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Path%20API%20Design/STANDARD_formate_Resolve_Device_Gateway_API_Test.ipynb)

# %%
Resolve_Device_Gateway_url = nb_url + "/ServicesAPI/API/V1/CMDB/Path/Gateways"
results = []
def resolve_device_gateway(Resolve_Device_Gateway_url, token, ipOrHost, headers):
    headers["Token"] = token
    data = {"ipOrHost":ipOrHost}
    try:
        response = requests.get(Resolve_Device_Gateway_url, params = data, headers = headers, verify = False)
        if response.status_code == 200:
            result = response.json()
            return (result)
        else:
            return ("Create module attribute failed! - " + str(response.text))

    except Exception as e:
        print (str(e)) 
        
for i in range(len(ips)):
    result = resolve_device_gateway(Resolve_Device_Gateway_url, token, ips[i], headers)
    #results.append(result["gatewayList"])
    #if result["gatewayList"] != ""
    res = result["gatewayList"]
    results.append(res)
    #print (res)
#result = resolve_device_gateway(Resolve_Device_Gateway_url, token, ips[0], headers)
#result["gatewayList"]
print(str(len(results)))
results
# Out:
# 88
# [[{'ip': '192.168.28.204', 'devName': 'R20', 'intfName': 'Ethernet0/1'}],
#  [{'ip': '123.10.1.10', 'devName': 'R3', 'intfName': 'Ethernet0/1'}],
#  [{'ip': '123.10.1.17', 'devName': 'R2', 'intfName': 'Ethernet0/2'}],
#  [{'ip': '123.10.1.1', 'devName': 'R4', 'intfName': 'Ethernet0/1'}],
#  [{'ip': '123.10.1.2', 'devName': 'R1', 'intfName': 'Ethernet0/2'}],
#  [{'ip': '123.10.1.6', 'devName': 'R5', 'intfName': 'Ethernet0/1'}],
#  [{'ip': '123.10.1.22', 'devName': 'R6', 'intfName': 'Ethernet0/2'}],
#  [{'ip': '123.7.7.7', 'devName': 'R7', 'intfName': 'Loopback0'}],
#  [{'ip': '123.8.8.8', 'devName': 'R8', 'intfName': 'Loopback0'}],
#  [{'ip': '123.10.10.10', 'devName': 'R10', 'intfName': 'Loopback0'}],
#  [{'ip': '123.11.11.11', 'devName': 'R11', 'intfName': 'Loopback0'}],
#  [{'ip': '123.9.9.9', 'devName': 'R9', 'intfName': 'Loopback0'}],
#  [{'ip': '123.203.3.3', 'devName': 'SW3', 'intfName': 'Loopback0'}],
#  [{'ip': '123.204.4.4', 'devName': 'SW4', 'intfName': 'Loopback0'}],
#  [{'ip': '123.15.15.15', 'devName': 'R15', 'intfName': 'Loopback0'}],
#  [{'ip': '123.20.1.11', 'devName': 'SW6', 'intfName': 'Vlan66'}],
#  [{'ip': '123.20.1.3', 'devName': 'SW5', 'intfName': 'Vlan55'}],
#  [{'ip': '123.20.1.10', 'devName': 'R17', 'intfName': 'Ethernet0/1'}],
#  [{'ip': '123.20.1.2', 'devName': 'R16', 'intfName': 'Ethernet0/1'}],
#  [{'ip': '10.18.19.18', 'devName': 'R18', 'intfName': 'Tunnel0'}],
#  [{'ip': '123.12.12.12', 'devName': 'R12', 'intfName': 'Loopback0'}],
#  [{'ip': '10.1.12.2', 'devName': 'Client1', 'intfName': 'Ethernet0/0'}],
#  [{'ip': '123.13.13.13', 'devName': 'R13', 'intfName': 'Loopback0'}],
#  [{'ip': '10.1.13.2', 'devName': 'Client2', 'intfName': 'Ethernet0/0'}],
#  [{'ip': '123.14.14.14', 'devName': 'R14', 'intfName': 'Loopback0'}],
#  [{'ip': '10.1.14.2', 'devName': 'Client3', 'intfName': 'Ethernet0/0'}],
#  [{'ip': '10.54.221.66', 'devName': 'R01FOB011', 'intfName': 'int-vlan100'}],
#  [{'ip': '172.21.31.254', 'devName': 'acr07jcsntn', 'intfName': 'Vlan160'}],
#  [{'ip': '172.21.28.33', 'devName': 'acr09jcsntn', 'intfName': 'Vlan7'}],
#  [{'ip': '172.31.224.21', 'devName': 'bbr02euclwi', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.83.7', 'devName': 'crr01jcsntn', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.18', 'devName': 'sar04euclwi', 'intfName': 'Loopback0'}],
#  [{'ip': '123.19.19.19', 'devName': 'R19', 'intfName': 'Loopback0'}],
#  [{'ip': '10.108.64.254',
#    'devName': '3XSQ-COREWAN-PE2',
#    'intfName': 'Loopback0'}],
#  [{'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'Loopback0'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16010'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16011'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16012'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16013'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16014'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16016'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16065'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16070'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16075'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16080'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16085'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16090'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16095'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16100'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16105'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16190'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16195'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16200'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16205'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16210'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16215'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16220'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16225'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16230'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16235'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16240'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16245'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16250'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16255'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16260'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16265'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16324'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16331'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16338'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16368'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16401'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16922'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16929'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16936'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te16943'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te17151'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te17156'},
#   {'ip': '10.108.64.29',
#    'devName': 'CME-COREWAN-PE4',
#    'intfName': 'tunnel-te17161'}],
#  [{'ip': '10.108.80.19',
#    'devName': 'DTC-COREWAN-PE2',
#    'intfName': 'Loopback0'},
#   {'ip': '10.108.80.19',
#    'devName': 'DTC-COREWAN-PE2',
#    'intfName': 'tunnel-te45002'}],
#  [{'ip': '10.108.64.23',
#    'devName': 'EGE-COREWAN-PE4',
#    'intfName': 'Loopback0'}],
#  [{'ip': '10.108.64.41',
#    'devName': 'HDC-COREWAN-PE6',
#    'intfName': 'Loopback0'},
#   {'ip': '10.108.64.41',
#    'devName': 'HDC-COREWAN-PE6',
#    'intfName': 'tunnel-te531'}],
#  [{'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'Loopback0'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te1601'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16010'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16012'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16013'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16014'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16015'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16091'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16326'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16333'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16340'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16342'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16344'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16346'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16348'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16924'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16931'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16938'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16945'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16947'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16949'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16951'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16953'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te16955'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te17144'},
#   {'ip': '10.108.64.27',
#    'devName': 'NJH-COREWAN-PE2',
#    'intfName': 'tunnel-te17146'}],
#  [{'ip': '10.108.64.17',
#    'devName': 'NTC-COREWAN-PE2',
#    'intfName': 'Loopback0'},
#   {'ip': '10.108.64.17',
#    'devName': 'NTC-COREWAN-PE2',
#    'intfName': 'tunnel-te531'}],
#  [{'ip': '10.108.64.33',
#    'devName': 'NY8-COREWAN-PE2',
#    'intfName': 'Loopback0'}],
#  [{'ip': '10.108.64.48',
#    'devName': 'OCB-COREWAN-PE4',
#    'intfName': 'Loopback0'}],
#  [{'ip': '162.8.250.239',
#    'devName': 'OCD-COREWAN-PE4',
#    'intfName': 'Loopback0'}],
#  [{'ip': '10.108.88.30',
#    'devName': 'PLN-COREWAN-PE2',
#    'intfName': 'TenGigabitEthernet1/1'}],
#  [{'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'Loopback0'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16001'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16002'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16003'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16004'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16091'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16092'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16093'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16094'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16095'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16096'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16186'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16271'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16272'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16273'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16274'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16275'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16319'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16320'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16348'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16349'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16386'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16388'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16389'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16390'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16395'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te16397'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17042'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17049'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17063'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17070'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17077'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17084'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17091'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17098'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17105'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17112'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te17119'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te45002'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te45004'},
#   {'ip': '10.108.80.41',
#    'devName': 'TN2-COREWAN-PE2',
#    'intfName': 'tunnel-te45006'}],
#  [{'ip': '172.31.224.70', 'devName': 'bar01cntlco', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.110', 'devName': 'bbr01aldlmi', 'intfName': 'Loopback0'}],
#  [{'ip': '96.34.192.120', 'devName': 'bbr01chcgil', 'intfName': 'Loopback15'}],
#  [{'ip': '172.31.224.130', 'devName': 'bbr01dnvrco', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.40', 'devName': 'bbr01olvemo', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.100', 'devName': 'bbr01oxfrma', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.111', 'devName': 'bbr01sgnwmi', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.121', 'devName': 'bbr02chcgil', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.75.8', 'devName': 'crr02oxfrma', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.64.66', 'devName': 'sar02bodcma', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.20', 'devName': 'bbr01euclwi', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.131', 'devName': 'bbr02dnvrco', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.40.72', 'devName': 'crr01euclwi', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.40.76', 'devName': 'crr01ftbgwi', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.40.7', 'devName': 'crr01onlswi', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.40.36', 'devName': 'dtr01euclwi', 'intfName': 'Loopback0'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2500'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2501'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2502'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2503'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2504'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2505'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2506'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2507'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2508'},
#   {'ip': '172.31.40.36',
#    'devName': 'dtr01euclwi',
#    'intfName': 'tunnel-ip2509'}],
#  [{'ip': '172.31.37.4', 'devName': 'dtr03jnvlwi', 'intfName': 'Loopback0'}],
#  [{'ip': '172.18.27.1', 'devName': 'nxs01euclwi', 'intfName': 'Vlan800'}],
#  [{'ip': '172.31.181.25', 'devName': 'acr01csbyor', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.181.26', 'devName': 'acr01rsbgor', 'intfName': 'Loopback0'}],
#  [{'ip': '172.27.146.241', 'devName': 'acr02lnbhca', 'intfName': 'Vlan18'}],
#  [{'ip': '172.31.176.222', 'devName': 'crr01mtpkca', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.176.223', 'devName': 'crr02mtpkca', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.181.34', 'devName': 'dtr01csbyor', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.176.18', 'devName': 'dtr01lnbhca', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.181.21', 'devName': 'dtr01rsbgor', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.176.19', 'devName': 'dtr02lnbhca', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.176.13', 'devName': 'dtr03mtpkca', 'intfName': 'Loopback0'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2500'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2501'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2502'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2503'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2504'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2505'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2506'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2507'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2508'},
#   {'ip': '172.31.176.13',
#    'devName': 'dtr03mtpkca',
#    'intfName': 'tunnel-ip2509'}],
#  [{'ip': '172.31.224.32', 'devName': 'prr01lsanca', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.224.140', 'devName': 'bbr01gdisne', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.198.173', 'devName': 'crr01gdisne', 'intfName': 'lo0.0'}],
#  [{'ip': '172.31.198.152', 'devName': 'dtr01krnyne', 'intfName': 'Loopback0'}],
#  [{'ip': '172.31.198.133', 'devName': 'sar01krnyne', 'intfName': 'loopback0'}],
#  [{'ip': '172.31.224.17', 'devName': 'sar03euclwi', 'intfName': 'Loopback0'}],
#  [{'ip': '66.109.2.255',
#    'devName': 'ATLNGAMQ46W-BCR00',
#    'intfName': 'Loopback0'}],
#  [{'ip': '71.66.63.30',
#    'devName': 'chrc1-h01-h01-video-4500-2',
#    'intfName': 'Loopback0'}],
#  [{'ip': '71.66.60.54',
#    'devName': 'chrcnctr01-rtr04',
#    'intfName': 'Bundle-Ether14'}],
#  [{'ip': '66.109.2.97',
#    'devName': 'CHRCNCTR04H-BAR03',
#    'intfName': 'Loopback0'}],
#  [{'ip': '66.109.2.250',
#    'devName': 'DLLSTX976IW-BCR00',
#    'intfName': 'Loopback0'}],
#  [{'ip': '66.109.2.99',
#    'devName': 'ENWDCOCD0AW-BAR03',
#    'intfName': 'Loopback0'}],
#  [{'ip': '66.109.2.249',
#    'devName': 'HSTQTX0209W-BCR00',
#    'intfName': 'Loopback0'}],
#  [{'ip': '10.104.130.84', 'devName': 'aa-dev-lb-rhp-1', 'intfName': 'mgmt'}],
#  [{'ip': '10.104.130.85', 'devName': 'aa-dev-lb-rhp-2', 'intfName': 'mgmt'}]]

# %% [markdown]
# ## Step 8: Calling Calculate Path API
# During this step, we are going to calling the Calculate Path API and set the gateway information list as one input(other inputs are shown in following code cell). When calling this API, users must input the required parameters correctly and follow the format of each inputs examples([Github_calPath](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Path%20API%20Design/STANDARD_formate_Calculate_Path_API_Test.ipynb)). After calling this API successfully, we will get the corresponding taskId of gateway information which has been put in. And the taskId is the only one required input for next step. If users want to get more details about this API or get errors when calling this API please check the API documentation on [Github_calPath](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Path%20API%20Design/STANDARD_formate_Calculate_Path_API_Test.ipynb).

# %%
from random import randint

Calculate_Path_url = nb_url + "/ServicesAPI/API/V1/CMDB/Path/Calculation"

def calculate_path(Calculate_Path_url, body, headers, token):
    headers["Token"] = token
    
    try:
        response = requests.post(Calculate_Path_url, data = json.dumps(body), headers = headers, verify = False)
        if response.status_code == 200:
            result = response.json()
            return (result["taskID"])
        else:
            return ("Create module attribute failed! - " + str(response.text))

    except Exception as e:
        return (str(e)) 

ress = []    
for i in range(len(results)):
    gw = results[i][0]

    j = randint(0, len(results))
    gw1 = results[j][0]

    if i != j:
        sourceIP = gw["ip"]
        sourcePort = 0
        sourceGwIP = gw["ip"]
        sourceGwDev = gw["devName"]
        sourceGwIntf = gw["intfName"]
        destIP = gw1["ip"]
        destPort = 0
        pathAnalysisSet = 2
        protocol = 4
        isLive = False

        body = {
                        "sourceIP" : sourceIP,                # IP address of the source device.
                        "sourcePort" : sourcePort,
                        "sourceGwDev" : sourceGwDev,          # Hostname of the gateway device.
                        "sourceGwIP" : sourceGwIP,            # Ip address of the gateway device.
                        "sourceGwIntf" : sourceGwIntf,        # Name of the gateway interface.
                        "destIP" : destIP,                    # IP address of the destination device.
                        "destPort" : destPort,
                        "pathAnalysisSet" : pathAnalysisSet,  # 1:L3 Path; 2:L2 Path; 3:L3 Active Path
                        "protocol" : protocol,                # Specify the application protocol, check online help, such as 4 for IPv4.
                        "isLive" : isLive                     # False: Current Baseline; True: Live access
            } 

        res = calculate_path(Calculate_Path_url, body, headers, token)
        ress.append(res)

print(str(len(ress)))
ress
# Out:
# 7
# 86
# ['e0e3cd5d-7a89-4066-a624-adc46e9a96bf',
#  'caec9050-a6d2-4cba-be8c-4600ac9318d2',
#  'd3b8bd4f-2cf7-4afd-a643-40409a2d140f',
#  '105ecc56-0035-4a98-aaad-f27180f26c13',
#  'cc7237b7-a02a-45c1-a540-29e9a7853902',
#  'c90a2abf-a8db-4d6a-891d-45b56d696f75',
#  '3e0d04e7-18c5-4cf6-a7e5-d35c3e4298f6',
#  'b8cbb197-18a2-48f5-a30c-925b25fc1f7c',
#  '86b3eff3-78d7-4990-ae02-dcf138b3d722',
#  '3635d87f-53b9-403c-91de-56e44a3eb447',
#  '6982b17b-e4a8-4426-8dd4-66ab39ccae86',
#  '036a447c-c4f5-459e-a52f-65da5073e1a5',
#  '2e877bd5-f9d1-4f22-8878-4e4be15989f6',
#  '9685cdcd-748c-4dc6-a74a-09f3557df5d6',
#  '72621b05-f4db-4508-9e68-7d9058902e2d',
#  'b84cb313-d2b3-402f-9777-5cc437bc78a5',
#  '3d6b42fb-a464-45ab-ab52-e89375a1b7c4',
#  '8a034f62-5069-4de3-8dba-cc5733bd5d05',
#  '1cdcb0b6-d520-43f3-b679-bf479957f104',
#  '2e68f259-fb65-4ef2-ab09-c79cfc49391b',
#  '5e92c88e-0925-49fc-a0d2-bff8596b266f',
#  '30249cb5-258f-4712-b2a3-e038ed154cfc',
#  '9691333e-1956-48c6-9b59-503afa0f54c0',
#  '0796eefb-23b6-4a0a-9aad-8d50494fb179',
#  '30c2d182-7db5-4170-8b35-cf02a0e73a7f',
#  'f251f4ab-b978-4d62-a55e-fc0a3436b12b',
#  'e9a5b137-585a-4913-ae5d-1370b5e6a306',
#  '2fc61207-36e1-4ae5-a5f6-f0d86fff247c',
#  '7f2e15b6-180a-41d6-8c91-363a61d96819',
#  'c1426bdd-d9da-4605-9443-ff4a8243f8b6',
#  'cde09bbc-1f7d-4305-be1b-689ad0d923cd',
#  '807d8bbf-14ae-474c-9442-40118ff2c40d',
#  '5a977752-cdbc-4ca7-b78f-8c9b9857f3ba',
#  'e6f8a682-805d-4b0d-b976-efa9440aa6ea',
#  'e60fbdd3-a028-4cfe-9dea-30c1fd5ebfa6',
#  'd5340f08-30a0-4029-854d-66f0007ac551',
#  '3aaa5968-7dfc-4883-ab10-e239ae423f42',
#  'c942cee0-d6dd-492c-902e-e3f75f7dbe71',
#  'bdd88f96-de25-4da0-ab37-925c9f7e7e95',
#  'e6838c8d-4993-407f-92d6-2c4ab6061749',
#  '91e70b03-2a96-4180-b6b3-2fe4b2f6e6ca',
#  '2ea0cb2d-3079-480f-9546-253550acea47',
#  'bb5590bd-5f30-4e8e-a68a-b53d56d4c66d',
#  '502fba1b-f1de-49d3-97cc-257b96b52363',
#  '06cab8ed-5410-406d-85e3-488cf16edc54',
#  '2e386b95-28da-4c56-9300-051b7ee76357',
#  '93683b40-668b-4f17-8f52-c78cd9d64052',
#  'b80cab17-c7cb-4b01-b1c8-0527f7ed5bb6',
#  '729229ff-053e-4122-aaa3-6c83768b2868',
#  '3e3ac527-068d-408c-96a0-d5c37dab44fb',
#  'e6ab066f-03d1-491b-bca6-1e290ccc1dc4',
#  '47eb670a-6e49-4ff9-9375-0af08584ed1d',
#  '739a9f95-3ec4-41e4-af44-8aba74ba3121',
#  '30316f92-f29e-491e-a149-3f2486cc2226',
#  'aa56aa68-8b1a-41c3-bf8a-b0582103975d',
#  'f50941b9-444b-4919-9938-8673752b1a03',
#  '0d3fc4ad-77fb-4113-9c83-180322d727d3',
#  'ea2ffc43-228b-4190-94b1-a82bfda96922',
#  '678aa1d3-4585-4ad5-a69e-07da47c1aa92',
#  '9420ac2c-afdb-4ccf-9b65-0a2090ac8558',
#  '7591d008-47f1-4b7f-a4ae-26fd57069b09',
#  'be344329-3f34-4009-8eef-552b3bbb49f8',
#  '877bf50a-3628-4fab-952e-4b2d17f42ce1',
#  '2dc6de16-52d3-40d1-b5d8-ce2cf87c48a7',
#  'bc497aeb-0c3c-4dd5-b427-e445ee7f5c4e',
#  '5629bc93-e21d-4944-b34c-c3c01b9a4151',
#  '753cb8a2-aabe-4f1b-84a2-abc933b0b2a8',
#  '389cba14-de02-4531-9385-a66008496770',
#  '208416f6-a894-41bd-9817-aa62ac3d7491',
#  '62ec37be-f3d7-4dbe-83a3-bef6b64d1884',
#  'b797b263-0edf-47c9-8908-e926379e5faa',
#  'd9fad4d2-678a-4cb1-bb17-7c0cb07685a0',
#  'd8cde8a7-000f-4654-90a7-0115f5328ebe',
#  '890c5ce1-019d-4cd2-9007-eae8f84f17da',
#  'd53f8f97-d274-4e37-8b8c-7ea989eaea22',
#  '2b4b9ac4-bc49-4c22-8e6c-1750247d043a',
#  'f278616f-a254-4554-b59c-d7d77a4b21ba',
#  'dfccf77d-3a4d-4a8d-af39-f1a97014cac1',
#  '9df40ecd-849f-4edf-9eb5-fe62c505a45e',
#  '8ac33e87-fe47-44ca-be7c-580639bb58ca',
#  '2d78f1be-4bd4-4bce-8bf7-13969590f44c',
#  '39154a68-eaf3-4495-b74e-8d609f19f10e',
#  'b705d24c-1a09-4102-8239-0996898f3c6d',
#  'bff91857-c97f-4867-9124-bdc57453849d',
#  'f1da66e3-bd45-4ad2-a211-e6075e3cd46e',
#  '476955e0-0d92-4732-a806-e31249d1b403']

# %%
print(str(len(ress[0])))
# Out:
# 36

# %% [markdown]
# ## Step 9: Calling Get Path Calulation Result API
# Now we attemp to the final functional step of this use case: to get the calculation result of the task which we have got the taskId in Step 8. After we running the following sample code successfully, we will finally get the path result in a json file. If users want to get more details about this API or get errors when calling this API please check the API documentation on [Github_pathRes](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Path%20API%20Design/STANDARD_formate_Get_Path_Calculation_Result_API_Test.ipynb).

# %%
import time
#time.sleep(30)   # Delays for 5 seconds. You can also use a float value.
def get_patth_result(Get_Path_Calulation_Result_url, headers, token):
    headers["Token"] = token
    try:
        response = requests.get(Get_Path_Calulation_Result_url, headers = headers, verify = False)
        if response.status_code == 200:
            result = response.json()
            return (result.json())
        else:
            return (response.json())

    except Exception as e:
        return (str(e)) 

Final = []
for i in range(len(ress)):
    if len(ress[i]) <= 36:
        time.sleep(3)   # Delays for 5 seconds. You can also use a float value.
        Get_Path_Calulation_Result_url = nb_url + "/ServicesAPI/API/V1/CMDB/Path/Calculation/" + str(ress[i]) + "/Result"
        final = get_patth_result(Get_Path_Calulation_Result_url, headers, token)
        d = json.dumps(final)
        j = json.loads(d)
        Final.append(final)
    
Final
# Out:
# [{'hopList': [{'hopId': '2a07dd34-0582-4e6a-bf4b-0cbf38c7ea9f',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['ee8dc147-ecb8-4b91-aefb-2d36de3b1686']},
#    {'hopId': 'ee8dc147-ecb8-4b91-aefb-2d36de3b1686',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'e0e3cd5d-7a89-4066-a624-adc46e9a96bf' is failed"},
#  {'hopList': [{'hopId': '6dbb6106-368c-4f0a-a04e-25613ba17fc0',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '123.10.1.8/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['7e65023d-a59c-4d3e-a8e6-2fcad9debd2d']},
#    {'hopId': '7e65023d-a59c-4d3e-a8e6-2fcad9debd2d',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['b1beb97a-59c4-4fd2-b2fc-f3536d563063']},
#    {'hopId': 'b1beb97a-59c4-4fd2-b2fc-f3536d563063',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['77c71b77-cf6e-4a18-be29-267202799e24']},
#    {'hopId': '77c71b77-cf6e-4a18-be29-267202799e24',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'caec9050-a6d2-4cba-be8c-4600ac9318d2' is failed"},
#  "'dict' object has no attribute 'json'",
#  {'hopList': [{'hopId': 'd3c2a67d-918b-48e8-bd0f-ded8b95e2e84',
#     'srcDeviceName': 'R4',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.16/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['5a8fd69d-d9c3-41dd-abdc-f8706663aff1']},
#    {'hopId': '5a8fd69d-d9c3-41dd-abdc-f8706663aff1',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['a8259011-708f-4776-a744-9cdc779054e9']},
#    {'hopId': 'a8259011-708f-4776-a744-9cdc779054e9',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['9a6d98ba-c592-484c-9ec7-c5436112b8e3']},
#    {'hopId': '9a6d98ba-c592-484c-9ec7-c5436112b8e3',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '105ecc56-0035-4a98-aaad-f27180f26c13' is failed"},
#  {'hopList': [{'hopId': 'ce6ccf59-0937-4c89-800f-3d060b36d06a',
#     'srcDeviceName': 'R1',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.0/30',
#     'dstDeviceName': 'R4',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['46fc1378-2bd3-49d3-af28-d74c129fee39']},
#    {'hopId': '46fc1378-2bd3-49d3-af28-d74c129fee39',
#     'srcDeviceName': 'R4',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.16/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['88e2d137-fea5-4c6d-b0e4-71bcf4f15064']},
#    {'hopId': '88e2d137-fea5-4c6d-b0e4-71bcf4f15064',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['3994bc36-00d9-423c-96f1-6211352c536a']},
#    {'hopId': '3994bc36-00d9-423c-96f1-6211352c536a',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['d576659d-740e-470f-a21b-94b9512f93d4']},
#    {'hopId': 'd576659d-740e-470f-a21b-94b9512f93d4',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'cc7237b7-a02a-45c1-a540-29e9a7853902' is failed"},
#  {'hopList': [{'hopId': 'e1ee229c-2c35-4022-a5c3-a70b7e22df27',
#     'srcDeviceName': 'R5',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.12/30',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['59685edc-7283-4f5c-a4ec-32eb93bbc9cf']},
#    {'hopId': '59685edc-7283-4f5c-a4ec-32eb93bbc9cf',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '123.10.1.8/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['ed521b42-b2fa-4f8d-9c29-7c1568106432']},
#    {'hopId': 'ed521b42-b2fa-4f8d-9c29-7c1568106432',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['edf8a776-c258-4737-a1e7-da1fdf80aa85']},
#    {'hopId': 'edf8a776-c258-4737-a1e7-da1fdf80aa85',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['86dc979b-0600-4323-a4a8-7718ff7030c4']},
#    {'hopId': '86dc979b-0600-4323-a4a8-7718ff7030c4',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'c90a2abf-a8db-4d6a-891d-45b56d696f75' is failed"},
#  {'hopList': [{'hopId': '6af8cc63-3aad-42bd-821f-2625b6ca6bad',
#     'srcDeviceName': 'R6',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.20/30',
#     'dstDeviceName': 'R4',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['c2ca5f23-0923-4c84-99fb-48c77dc5c002']},
#    {'hopId': 'c2ca5f23-0923-4c84-99fb-48c77dc5c002',
#     'srcDeviceName': 'R4',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.16/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['005b7faa-0df9-4998-9f60-e80213b5fa55']},
#    {'hopId': '005b7faa-0df9-4998-9f60-e80213b5fa55',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['6307fbd1-d0f8-4ea8-b615-d5be2644f559']},
#    {'hopId': '6307fbd1-d0f8-4ea8-b615-d5be2644f559',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['ae78e003-3f35-4f20-9476-dc3bcdaaf427']},
#    {'hopId': 'ae78e003-3f35-4f20-9476-dc3bcdaaf427',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '3e0d04e7-18c5-4cf6-a7e5-d35c3e4298f6' is failed"},
#  {'hopList': [{'hopId': 'bd812ff2-caba-45ed-a41f-38e816731286',
#     'srcDeviceName': 'R7',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '123.10.1.24/30',
#     'dstDeviceName': 'R6',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['64126079-f669-46f9-9565-990e60feb9c9']},
#    {'hopId': '64126079-f669-46f9-9565-990e60feb9c9',
#     'srcDeviceName': 'R6',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.20/30',
#     'dstDeviceName': 'R4',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['9bcd864b-0389-47f2-93d6-20042ea243d7']},
#    {'hopId': '9bcd864b-0389-47f2-93d6-20042ea243d7',
#     'srcDeviceName': 'R4',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.16/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['b5962830-53f9-4fb1-aa78-53d0400d71ab']},
#    {'hopId': 'b5962830-53f9-4fb1-aa78-53d0400d71ab',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['c885e3a5-a479-430d-80dc-86a06821700f']},
#    {'hopId': 'c885e3a5-a479-430d-80dc-86a06821700f',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['3f945b5b-703b-49bc-b0e3-e15176dc53cb']},
#    {'hopId': '3f945b5b-703b-49bc-b0e3-e15176dc53cb',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []},
#    {'hopId': '92bdd4c7-4490-4c96-98b6-23bd8935143b',
#     'srcDeviceName': 'R7',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.28/30',
#     'dstDeviceName': 'R5',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['8b1db2ba-8ef9-41a5-a33a-be1ff7e36663']},
#    {'hopId': '8b1db2ba-8ef9-41a5-a33a-be1ff7e36663',
#     'srcDeviceName': 'R5',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.12/30',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['95055a14-2d93-4007-a726-1a482cd65c52']},
#    {'hopId': '95055a14-2d93-4007-a726-1a482cd65c52',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '123.10.1.8/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['b5962830-53f9-4fb1-aa78-53d0400d71ab']}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'b8cbb197-18a2-48f5-a30c-925b25fc1f7c' is failed"},
#  {'hopList': [{'hopId': 'b4a96a8a-4ecc-40e4-bb33-fe9e2515e010',
#     'srcDeviceName': 'R8',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'SW3',
#     'outboundInterface': 'Ethernet0/0',
#     'nextHopIdList': ['3d70cdfe-5d4c-4601-ba8a-293d6c0ad3f1']},
#    {'hopId': '3d70cdfe-5d4c-4601-ba8a-293d6c0ad3f1',
#     'srcDeviceName': 'SW3',
#     'inboundInterface': 'Ethernet2/0',
#     'mediaName': '',
#     'dstDeviceName': 'SW4',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['9359600d-7480-4738-af89-3dba9fc314ae']},
#    {'hopId': '9359600d-7480-4738-af89-3dba9fc314ae',
#     'srcDeviceName': 'SW4',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'R9',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['ac7a5f3d-7dcc-432a-a5c0-1201eab3d3a9']},
#    {'hopId': 'ac7a5f3d-7dcc-432a-a5c0-1201eab3d3a9',
#     'srcDeviceName': 'R9',
#     'inboundInterface': 'Ethernet1/0',
#     'mediaName': '33.34.4.0/30',
#     'dstDeviceName': 'AS30000',
#     'outboundInterface': 'Ethernet1/0-33.34.4.1',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '86b3eff3-78d7-4990-ae02-dcf138b3d722' is failed"},
#  {'hopList': [{'hopId': '17058a6e-90c0-461d-96cb-efbc46ac77e2',
#     'srcDeviceName': 'R10',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '',
#     'dstDeviceName': 'SW4',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['c547faf4-58f5-4a33-970c-f909fd4eb46d']},
#    {'hopId': 'c547faf4-58f5-4a33-970c-f909fd4eb46d',
#     'srcDeviceName': 'SW4',
#     'inboundInterface': 'Ethernet2/0',
#     'mediaName': '',
#     'dstDeviceName': 'SW3',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['d5db92de-b028-4b03-b3fa-3d050f7aec8d',
#      'c314d079-b4f7-48ec-8cbb-5e6161ef9835']},
#    {'hopId': 'd5db92de-b028-4b03-b3fa-3d050f7aec8d',
#     'srcDeviceName': 'SW3',
#     'inboundInterface': 'Ethernet2/0',
#     'mediaName': '',
#     'dstDeviceName': 'SW4',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['c547faf4-58f5-4a33-970c-f909fd4eb46d']},
#    {'hopId': 'c314d079-b4f7-48ec-8cbb-5e6161ef9835',
#     'srcDeviceName': 'SW3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'R9',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['76d105b1-5fc6-4670-8216-f01cf61f3ac2']},
#    {'hopId': '76d105b1-5fc6-4670-8216-f01cf61f3ac2',
#     'srcDeviceName': 'R9',
#     'inboundInterface': 'Ethernet1/0',
#     'mediaName': '33.34.4.0/30',
#     'dstDeviceName': 'AS30000',
#     'outboundInterface': 'Ethernet1/0-33.34.4.1',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '3635d87f-53b9-403c-91de-56e44a3eb447' is failed"},
#  {'hopList': [{'hopId': '1c18f042-2bb3-41af-af07-e42b90cbf006',
#     'srcDeviceName': 'R11',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'SW3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['4e28ac02-c6ac-4343-a96f-f3f921ff61a1']},
#    {'hopId': '4e28ac02-c6ac-4343-a96f-f3f921ff61a1',
#     'srcDeviceName': 'SW3',
#     'inboundInterface': 'Ethernet2/0',
#     'mediaName': '',
#     'dstDeviceName': 'SW4',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['ad3ad189-c9e9-418c-a053-d9f4304023b0']},
#    {'hopId': 'ad3ad189-c9e9-418c-a053-d9f4304023b0',
#     'srcDeviceName': 'SW4',
#     'inboundInterface': 'Ethernet2/0',
#     'mediaName': '',
#     'dstDeviceName': 'SW3',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['a01d1862-c6f3-441a-9a62-ee70e5da2232']},
#    {'hopId': 'a01d1862-c6f3-441a-9a62-ee70e5da2232',
#     'srcDeviceName': 'SW3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'R9',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['c18debc3-a53d-4f2f-8796-d437c16762a6']},
#    {'hopId': 'c18debc3-a53d-4f2f-8796-d437c16762a6',
#     'srcDeviceName': 'R9',
#     'inboundInterface': 'Ethernet1/0',
#     'mediaName': '33.34.4.0/30',
#     'dstDeviceName': 'AS30000',
#     'outboundInterface': 'Ethernet1/0-33.34.4.1',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '6982b17b-e4a8-4426-8dd4-66ab39ccae86' is failed"},
#  {'hopList': [{'hopId': 'be9f9004-3359-4c47-a178-ccbc17085958',
#     'srcDeviceName': 'R9',
#     'inboundInterface': 'Ethernet1/0',
#     'mediaName': '33.34.4.0/30',
#     'dstDeviceName': 'AS30000',
#     'outboundInterface': 'Ethernet1/0-33.34.4.1',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '036a447c-c4f5-459e-a52f-65da5073e1a5' is failed"},
#  {'hopList': [{'hopId': 'b08db9aa-eaff-4ed9-ad01-094a727689be',
#     'srcDeviceName': 'SW3',
#     'inboundInterface': 'Ethernet2/0',
#     'mediaName': '',
#     'dstDeviceName': 'SW4',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['174749ab-567b-4df2-a4f9-723f467b1aa8']},
#    {'hopId': '174749ab-567b-4df2-a4f9-723f467b1aa8',
#     'srcDeviceName': 'SW4',
#     'inboundInterface': 'Ethernet2/0',
#     'mediaName': '',
#     'dstDeviceName': 'SW3',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['2fe27f78-9ffc-4165-a6b6-b36f2efa1691']},
#    {'hopId': '2fe27f78-9ffc-4165-a6b6-b36f2efa1691',
#     'srcDeviceName': 'SW3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'R9',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['1f5787af-b720-4b2e-a1aa-1310be3d50de']},
#    {'hopId': '1f5787af-b720-4b2e-a1aa-1310be3d50de',
#     'srcDeviceName': 'R9',
#     'inboundInterface': 'Ethernet1/0',
#     'mediaName': '33.34.4.0/30',
#     'dstDeviceName': 'AS30000',
#     'outboundInterface': 'Ethernet1/0-33.34.4.1',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '2e877bd5-f9d1-4f22-8878-4e4be15989f6' is failed"},
#  {'hopList': [{'hopId': '5ad519ed-3404-4e94-8e7c-62da47de296d',
#     'srcDeviceName': 'SW4',
#     'inboundInterface': 'Ethernet2/0',
#     'mediaName': '',
#     'dstDeviceName': 'SW3',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['96467a5e-3ff4-4b88-9b59-b3ddbb77fe7e']},
#    {'hopId': '96467a5e-3ff4-4b88-9b59-b3ddbb77fe7e',
#     'srcDeviceName': 'SW3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'R9',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['a0c1b7bc-21c7-475a-b05d-9bbcfcb22f9f']},
#    {'hopId': 'a0c1b7bc-21c7-475a-b05d-9bbcfcb22f9f',
#     'srcDeviceName': 'R9',
#     'inboundInterface': 'Ethernet1/0',
#     'mediaName': '33.34.4.0/30',
#     'dstDeviceName': 'AS30000',
#     'outboundInterface': 'Ethernet1/0-33.34.4.1',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '9685cdcd-748c-4dc6-a74a-09f3557df5d6' is failed"},
#  {'hopList': [{'hopId': '0cc1ddbe-588c-43b2-94ae-371278903f1e',
#     'srcDeviceName': 'R15',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '103.2.45.0/30',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0-103.2.45.1',
#     'nextHopIdList': ['d134eaa8-985b-4688-ac6e-735f14de8e9c',
#      '8ff7a114-bc97-4f79-bb0a-6b75c24b5b7a']},
#    {'hopId': 'd134eaa8-985b-4688-ac6e-735f14de8e9c',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-101.1.123.1(YELLOW)',
#     'mediaName': '101.1.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['fbc0cafc-33f5-43e2-ac4f-1b656a68d57b']},
#    {'hopId': 'fbc0cafc-33f5-43e2-ac4f-1b656a68d57b',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['bbb0ac40-c63f-40cc-8366-2aa9b7ce1c6e']},
#    {'hopId': 'bbb0ac40-c63f-40cc-8366-2aa9b7ce1c6e',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['f425529c-b51d-4428-8535-f9c3709be72a']},
#    {'hopId': 'f425529c-b51d-4428-8535-f9c3709be72a',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []},
#    {'hopId': '8ff7a114-bc97-4f79-bb0a-6b75c24b5b7a',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-102.2.123.1(YELLOW)',
#     'mediaName': '102.2.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['ad00ce0f-d6cf-4597-8f18-86b6f097c75f']},
#    {'hopId': 'ad00ce0f-d6cf-4597-8f18-86b6f097c75f',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet3/0',
#     'nextHopIdList': ['bbb0ac40-c63f-40cc-8366-2aa9b7ce1c6e']}],
#   'statusCode': 794008,
#   'statusDescription': "Task '72621b05-f4db-4508-9e68-7d9058902e2d' is failed"},
#  {'hopList': [{'hopId': '4dde8b5c-db44-4116-b191-3b5fce62864b',
#     'srcDeviceName': 'SW6',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '',
#     'dstDeviceName': 'R15',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['c8327e36-c83d-4657-abf9-8689740d5f42']},
#    {'hopId': 'c8327e36-c83d-4657-abf9-8689740d5f42',
#     'srcDeviceName': 'R15',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '103.2.45.0/30',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0-103.2.45.1',
#     'nextHopIdList': ['40dd887d-c540-475d-9453-1456658770b6',
#      'eca5eff8-79d8-494e-b378-1cf9d64a5f83']},
#    {'hopId': '40dd887d-c540-475d-9453-1456658770b6',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-101.1.123.1(YELLOW)',
#     'mediaName': '101.1.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['f019ffca-3fd8-48fe-9074-04c442cb7a58']},
#    {'hopId': 'f019ffca-3fd8-48fe-9074-04c442cb7a58',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['f1bba09a-436b-4cbc-b3cc-ebd1f70367c0']},
#    {'hopId': 'f1bba09a-436b-4cbc-b3cc-ebd1f70367c0',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['3e637b3c-e573-421d-9f24-312935ba0c5b']},
#    {'hopId': '3e637b3c-e573-421d-9f24-312935ba0c5b',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []},
#    {'hopId': 'eca5eff8-79d8-494e-b378-1cf9d64a5f83',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-102.2.123.1(YELLOW)',
#     'mediaName': '102.2.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['d467543e-5279-4cd0-a62a-80c0386127d4']},
#    {'hopId': 'd467543e-5279-4cd0-a62a-80c0386127d4',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet3/0',
#     'nextHopIdList': ['f1bba09a-436b-4cbc-b3cc-ebd1f70367c0']}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'b84cb313-d2b3-402f-9777-5cc437bc78a5' is failed"},
#  "'dict' object has no attribute 'json'",
#  {'hopList': [{'hopId': '0cb50345-d26e-4a12-be44-ef0be7e86599',
#     'srcDeviceName': 'R17',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'SW6',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['7ddffe49-f11d-4e58-8230-4d3a255dead1']},
#    {'hopId': '7ddffe49-f11d-4e58-8230-4d3a255dead1',
#     'srcDeviceName': 'SW6',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '',
#     'dstDeviceName': 'R15',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['15054a95-b264-4d18-83e0-54f9b358b90e']},
#    {'hopId': '15054a95-b264-4d18-83e0-54f9b358b90e',
#     'srcDeviceName': 'R15',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '103.2.45.0/30',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0-103.2.45.1',
#     'nextHopIdList': ['13af8a27-63c1-404a-95dc-df230b38fb0c',
#      'd38f6957-ac4e-4e4b-b1d5-1e651e9aa6d5']},
#    {'hopId': '13af8a27-63c1-404a-95dc-df230b38fb0c',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-101.1.123.1(YELLOW)',
#     'mediaName': '101.1.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['e9281c31-cc66-4439-bf51-d432b5c1b15b']},
#    {'hopId': 'e9281c31-cc66-4439-bf51-d432b5c1b15b',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['2a2d9697-9581-4a51-9f72-ccec55f73375']},
#    {'hopId': '2a2d9697-9581-4a51-9f72-ccec55f73375',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['f93454c0-dfd3-4986-bf43-83ec1bdaac07']},
#    {'hopId': 'f93454c0-dfd3-4986-bf43-83ec1bdaac07',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []},
#    {'hopId': 'd38f6957-ac4e-4e4b-b1d5-1e651e9aa6d5',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-102.2.123.1(YELLOW)',
#     'mediaName': '102.2.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['af9b4a73-d948-450b-a664-20685cf015f1']},
#    {'hopId': 'af9b4a73-d948-450b-a664-20685cf015f1',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet3/0',
#     'nextHopIdList': ['2a2d9697-9581-4a51-9f72-ccec55f73375']}],
#   'statusCode': 794008,
#   'statusDescription': "Task '8a034f62-5069-4de3-8dba-cc5733bd5d05' is failed"},
#  {'hopList': [{'hopId': '856c6c3e-f5cc-44e9-897b-7fc97ad2914e',
#     'srcDeviceName': 'R16',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'SW5',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['a43f7814-a722-48e8-98f6-d77b653e6b92']},
#    {'hopId': 'a43f7814-a722-48e8-98f6-d77b653e6b92',
#     'srcDeviceName': 'SW5',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '',
#     'dstDeviceName': 'R15',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['d7baced1-6a35-4b46-b943-5fb8854ff7cf']},
#    {'hopId': 'd7baced1-6a35-4b46-b943-5fb8854ff7cf',
#     'srcDeviceName': 'R15',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '103.2.45.0/30',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0-103.2.45.1',
#     'nextHopIdList': ['ad9c0b31-59f1-448b-895f-adb791a04281',
#      'd5ae07f7-3ee8-48b3-b294-5b6e68964f5d']},
#    {'hopId': 'ad9c0b31-59f1-448b-895f-adb791a04281',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-101.1.123.1(YELLOW)',
#     'mediaName': '101.1.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['e796138d-8fd8-4282-86ed-a15e843bde6c']},
#    {'hopId': 'e796138d-8fd8-4282-86ed-a15e843bde6c',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['b4153590-32ae-4227-8e33-142782da62de']},
#    {'hopId': 'b4153590-32ae-4227-8e33-142782da62de',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['1d078a95-781d-444d-8593-5192b0a87e2a']},
#    {'hopId': '1d078a95-781d-444d-8593-5192b0a87e2a',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []},
#    {'hopId': 'd5ae07f7-3ee8-48b3-b294-5b6e68964f5d',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-102.2.123.1(YELLOW)',
#     'mediaName': '102.2.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['75a2354e-1eb5-4da2-a3fe-4b633b30ea43']},
#    {'hopId': '75a2354e-1eb5-4da2-a3fe-4b633b30ea43',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet3/0',
#     'nextHopIdList': ['b4153590-32ae-4227-8e33-142782da62de']}],
#   'statusCode': 794008,
#   'statusDescription': "Task '1cdcb0b6-d520-43f3-b679-bf479957f104' is failed"},
#  {'hopList': [{'hopId': 'd3138833-b1d0-41f3-9c6d-26e2a073c503',
#     'srcDeviceName': 'R18',
#     'inboundInterface': 'Serial4/0',
#     'mediaName': '203.3.18.0/30',
#     'dstDeviceName': 'AS20003',
#     'outboundInterface': 'Serial4/0-203.3.18.1',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '2e68f259-fb65-4ef2-ab09-c79cfc49391b' is failed"},
#  {'hopList': [{'hopId': '808cdb76-7918-4a82-a381-bbc0109ef025',
#     'srcDeviceName': 'R12',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '201.1.12.0/30',
#     'dstDeviceName': 'AS20001',
#     'outboundInterface': 'Ethernet0/1-201.1.12.1',
#     'nextHopIdList': ['a8fcf11a-8a1e-4b04-8736-5bfc8667f154']},
#    {'hopId': 'a8fcf11a-8a1e-4b04-8736-5bfc8667f154',
#     'srcDeviceName': 'AS20001',
#     'inboundInterface': 'Ethernet0/0.12-201.1.123.1(GREEN)',
#     'mediaName': '201.1.123.0/30\r\nVRF:GREEN',
#     'dstDeviceName': 'R6',
#     'outboundInterface': 'Ethernet0/0.12',
#     'nextHopIdList': ['9a5cc04c-da32-42e7-88e5-10ff8ca2c2fa']},
#    {'hopId': '9a5cc04c-da32-42e7-88e5-10ff8ca2c2fa',
#     'srcDeviceName': 'R6',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.20/30',
#     'dstDeviceName': 'R4',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['ea4daa58-1a7c-46e9-82fb-5a02557b834b']},
#    {'hopId': 'ea4daa58-1a7c-46e9-82fb-5a02557b834b',
#     'srcDeviceName': 'R4',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.16/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['1ff4b5b0-429e-4804-9506-d7398a30d75d']},
#    {'hopId': '1ff4b5b0-429e-4804-9506-d7398a30d75d',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['dee00bdf-0463-4fb0-a9ec-ab8d95913486']},
#    {'hopId': 'dee00bdf-0463-4fb0-a9ec-ab8d95913486',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['11771fcd-2d17-444a-a0f0-0e09dd3f72e1']},
#    {'hopId': '11771fcd-2d17-444a-a0f0-0e09dd3f72e1',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '5e92c88e-0925-49fc-a0d2-bff8596b266f' is failed"},
#  "'dict' object has no attribute 'json'",
#  "'dict' object has no attribute 'json'",
#  {'hopList': [{'hopId': 'c0fdcc01-9b2e-465b-8d12-56fb946d5888',
#     'srcDeviceName': 'Client2',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '',
#     'dstDeviceName': 'R13',
#     'outboundInterface': 'Ethernet0/0',
#     'nextHopIdList': ['be52c5c3-528c-4bfe-93e6-539c6befb194']},
#    {'hopId': 'be52c5c3-528c-4bfe-93e6-539c6befb194',
#     'srcDeviceName': 'R13',
#     'inboundInterface': 'Serial1/1',
#     'mediaName': '202.2.13.0/30',
#     'dstDeviceName': 'AS20002',
#     'outboundInterface': 'Serial1/1-202.2.13.1',
#     'nextHopIdList': ['4ef2d471-1a9d-4d0c-897c-7d19170bd463']},
#    {'hopId': '4ef2d471-1a9d-4d0c-897c-7d19170bd463',
#     'srcDeviceName': 'AS20002',
#     'inboundInterface': 'Ethernet0/0.13-202.2.123.1(BLUE)',
#     'mediaName': '202.2.123.0/30\r\nVRF:BLUE',
#     'dstDeviceName': 'R7',
#     'outboundInterface': 'Ethernet0/0.13',
#     'nextHopIdList': ['365e3af9-99b6-49ff-97c4-4cf3a1826023',
#      'c2866e41-4fab-4797-97d2-d3d91052bc5e']},
#    {'hopId': '365e3af9-99b6-49ff-97c4-4cf3a1826023',
#     'srcDeviceName': 'R7',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '123.10.1.24/30',
#     'dstDeviceName': 'R6',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['fc88d547-0fbd-4fce-af0d-0e5b8b2f8993']},
#    {'hopId': 'fc88d547-0fbd-4fce-af0d-0e5b8b2f8993',
#     'srcDeviceName': 'R6',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.20/30',
#     'dstDeviceName': 'R4',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['a48f7de3-4861-47dc-b21c-a01f43ac094f']},
#    {'hopId': 'a48f7de3-4861-47dc-b21c-a01f43ac094f',
#     'srcDeviceName': 'R4',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.16/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['a6b237e1-bb1f-4610-a565-aef8f09ca2f0']},
#    {'hopId': 'a6b237e1-bb1f-4610-a565-aef8f09ca2f0',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['11342bc2-838f-4730-bdd7-165c615671c4']},
#    {'hopId': '11342bc2-838f-4730-bdd7-165c615671c4',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['5d40f6da-7661-424f-b90e-46da4f6206e0']},
#    {'hopId': '5d40f6da-7661-424f-b90e-46da4f6206e0',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []},
#    {'hopId': 'c2866e41-4fab-4797-97d2-d3d91052bc5e',
#     'srcDeviceName': 'R7',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.28/30',
#     'dstDeviceName': 'R5',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['a76b28d9-adad-436a-aa08-a9d34cfe35c7']},
#    {'hopId': 'a76b28d9-adad-436a-aa08-a9d34cfe35c7',
#     'srcDeviceName': 'R5',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.12/30',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['cdf0ff01-93d0-4bac-8205-1bf5ed3986ce']},
#    {'hopId': 'cdf0ff01-93d0-4bac-8205-1bf5ed3986ce',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '123.10.1.8/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['a6b237e1-bb1f-4610-a565-aef8f09ca2f0']}],
#   'statusCode': 794008,
#   'statusDescription': "Task '0796eefb-23b6-4a0a-9aad-8d50494fb179' is failed"},
#  "'dict' object has no attribute 'json'",
#  {'hopList': [{'hopId': '9e981d86-f8ef-4bca-af32-395459d45dcb',
#     'srcDeviceName': 'Client3',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '',
#     'dstDeviceName': 'R14',
#     'outboundInterface': 'Ethernet0/0',
#     'nextHopIdList': ['dd8ec46d-d449-4555-8364-9ac8bfdc86ad']},
#    {'hopId': 'dd8ec46d-d449-4555-8364-9ac8bfdc86ad',
#     'srcDeviceName': 'R14',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '202.2.14.0/30',
#     'dstDeviceName': 'AS20002',
#     'outboundInterface': 'Ethernet0/1-202.2.14.1',
#     'nextHopIdList': ['d5a8fd63-b0ee-4ccf-a752-93cea643258d']},
#    {'hopId': 'd5a8fd63-b0ee-4ccf-a752-93cea643258d',
#     'srcDeviceName': 'AS20002',
#     'inboundInterface': 'Ethernet0/0.14-202.2.123.1(RED)',
#     'mediaName': '202.2.123.0/30\r\nVRF:RED',
#     'dstDeviceName': 'R7',
#     'outboundInterface': 'Ethernet0/0.14',
#     'nextHopIdList': ['55a91800-e40f-4aac-92df-19fc259b9181',
#      '18e3d96a-9451-4696-8814-0f220d20881e']},
#    {'hopId': '55a91800-e40f-4aac-92df-19fc259b9181',
#     'srcDeviceName': 'R7',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '123.10.1.24/30',
#     'dstDeviceName': 'R6',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['49d32653-b67c-4d20-97e3-21ae01e11d1b']},
#    {'hopId': '49d32653-b67c-4d20-97e3-21ae01e11d1b',
#     'srcDeviceName': 'R6',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.20/30',
#     'dstDeviceName': 'R4',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['c3847ab0-e76d-430b-b26b-fa1ea71768dd']},
#    {'hopId': 'c3847ab0-e76d-430b-b26b-fa1ea71768dd',
#     'srcDeviceName': 'R4',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.16/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['9cf0e505-1172-4173-93b4-c8c4e5efba5e']},
#    {'hopId': '9cf0e505-1172-4173-93b4-c8c4e5efba5e',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['dc7e9be2-03a7-4bba-a339-d32b0675c0f8']},
#    {'hopId': 'dc7e9be2-03a7-4bba-a339-d32b0675c0f8',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['81cf75ac-3412-4f89-bc30-bfb1469859d3']},
#    {'hopId': '81cf75ac-3412-4f89-bc30-bfb1469859d3',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []},
#    {'hopId': '18e3d96a-9451-4696-8814-0f220d20881e',
#     'srcDeviceName': 'R7',
#     'inboundInterface': 'Ethernet0/2',
#     'mediaName': '123.10.1.28/30',
#     'dstDeviceName': 'R5',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['91ce7dd1-20fa-4404-93fd-57f7f5875f8d']},
#    {'hopId': '91ce7dd1-20fa-4404-93fd-57f7f5875f8d',
#     'srcDeviceName': 'R5',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '123.10.1.12/30',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['38478834-1a4b-460e-b75b-3544ec6b3f5a']},
#    {'hopId': '38478834-1a4b-460e-b75b-3544ec6b3f5a',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '123.10.1.8/30',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['9cf0e505-1172-4173-93b4-c8c4e5efba5e']}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'f251f4ab-b978-4d62-a55e-fc0a3436b12b' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'e9a5b137-585a-4913-ae5d-1370b5e6a306' is failed"},
#  {'hopList': [{'hopId': '4a8434e7-9a71-47bb-9a15-4a09ccce7a35',
#     'srcDeviceName': 'acr07jcsntn',
#     'inboundInterface': 'TenGigabitEthernet4/1',
#     'mediaName': '96.34.71.110/31',
#     'dstDeviceName': 'acr09jcsntn',
#     'outboundInterface': 'TenGigabitEthernet4/3',
#     'nextHopIdList': ['f4e7c2e2-9f84-462c-ade2-d0d4ae962e84',
#      '38b5afb1-76dd-4df9-80a1-f97c1126275a']},
#    {'hopId': 'f4e7c2e2-9f84-462c-ade2-d0d4ae962e84',
#     'srcDeviceName': 'acr09jcsntn',
#     'inboundInterface': 'TenGigabitEthernet7/2',
#     'mediaName': '',
#     'dstDeviceName': 'crr01jcsntn',
#     'outboundInterface': 'TenGigE0/3/0/1',
#     'nextHopIdList': []},
#    {'hopId': '38b5afb1-76dd-4df9-80a1-f97c1126275a',
#     'srcDeviceName': 'acr09jcsntn',
#     'inboundInterface': 'TenGigabitEthernet7/4',
#     'mediaName': '',
#     'dstDeviceName': 'crr01jcsntn',
#     'outboundInterface': 'TenGigE0/3/0/0',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '2fc61207-36e1-4ae5-a5f6-f0d86fff247c' is failed"},
#  {'hopList': [{'hopId': 'f35dd76c-3095-4fbd-be16-45f58d88afd0',
#     'srcDeviceName': 'acr09jcsntn',
#     'inboundInterface': 'TenGigabitEthernet7/2',
#     'mediaName': '',
#     'dstDeviceName': 'crr01jcsntn',
#     'outboundInterface': 'TenGigE0/3/0/1',
#     'nextHopIdList': []},
#    {'hopId': '862fd899-c8ae-413e-9d1b-2af949f107ab',
#     'srcDeviceName': 'acr09jcsntn',
#     'inboundInterface': 'TenGigabitEthernet7/4',
#     'mediaName': '',
#     'dstDeviceName': 'crr01jcsntn',
#     'outboundInterface': 'TenGigE0/3/0/0',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '7f2e15b6-180a-41d6-8c91-363a61d96819' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'c1426bdd-d9da-4605-9443-ff4a8243f8b6' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'cde09bbc-1f7d-4305-be1b-689ad0d923cd' is failed"},
#  {'hopList': [{'hopId': 'fffce02e-ce11-4e5e-8e98-384e9963d217',
#     'srcDeviceName': 'sar04euclwi',
#     'inboundInterface': 'Bundle-Ether500',
#     'mediaName': '96.34.2.250/31',
#     'dstDeviceName': 'bbr02euclwi',
#     'outboundInterface': 'Bundle-Ether500',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '807d8bbf-14ae-474c-9442-40118ff2c40d' is failed"},
#  {'hopList': [{'hopId': '08394b66-b353-453b-969d-af516a63cb1b',
#     'srcDeviceName': 'R19',
#     'inboundInterface': 'Tunnel0',
#     'mediaName': '10.18.19.0/24',
#     'dstDeviceName': 'R17',
#     'outboundInterface': 'Tunnel0',
#     'nextHopIdList': ['209f7195-cf83-473e-a0c9-5364bd63716d']},
#    {'hopId': '209f7195-cf83-473e-a0c9-5364bd63716d',
#     'srcDeviceName': 'R17',
#     'inboundInterface': 'Ethernet0/1',
#     'mediaName': '',
#     'dstDeviceName': 'SW6',
#     'outboundInterface': 'Ethernet0/1',
#     'nextHopIdList': ['d0d4cdd6-9571-4989-b1c7-22b1f46177f7']},
#    {'hopId': 'd0d4cdd6-9571-4989-b1c7-22b1f46177f7',
#     'srcDeviceName': 'SW6',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '',
#     'dstDeviceName': 'R15',
#     'outboundInterface': 'Ethernet0/2',
#     'nextHopIdList': ['6b2473c7-ea17-4cf3-a9d4-d73a6c972962']},
#    {'hopId': '6b2473c7-ea17-4cf3-a9d4-d73a6c972962',
#     'srcDeviceName': 'R15',
#     'inboundInterface': 'Ethernet0/0',
#     'mediaName': '103.2.45.0/30',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0-103.2.45.1',
#     'nextHopIdList': ['7a44cbb0-22f0-4ecc-9348-fae6b33be547',
#      '68c88c3a-13a2-41d5-ac7a-63b9966fc587']},
#    {'hopId': '7a44cbb0-22f0-4ecc-9348-fae6b33be547',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-101.1.123.1(YELLOW)',
#     'mediaName': '101.1.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R2',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['d27f1571-a2ca-4568-8441-601bcaf2dc06']},
#    {'hopId': 'd27f1571-a2ca-4568-8441-601bcaf2dc06',
#     'srcDeviceName': 'R2',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet2/0',
#     'nextHopIdList': ['23115c14-291d-41ee-9fbe-df023f24b667']},
#    {'hopId': '23115c14-291d-41ee-9fbe-df023f24b667',
#     'srcDeviceName': 'R20',
#     'inboundInterface': 'Ethernet3/0',
#     'mediaName': '',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/3',
#     'nextHopIdList': ['2c5576fc-927a-4207-88cf-55a20c760b2d']},
#    {'hopId': '2c5576fc-927a-4207-88cf-55a20c760b2d',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/0.99',
#     'mediaName': '102.2.123.0/30\r\nVRF:INET',
#     'dstDeviceName': 'ISP',
#     'outboundInterface': 'Ethernet0/0.99-102.2.123.1(INET)',
#     'nextHopIdList': []},
#    {'hopId': '68c88c3a-13a2-41d5-ac7a-63b9966fc587',
#     'srcDeviceName': 'ISP',
#     'inboundInterface': 'Ethernet0/0.15-102.2.123.1(YELLOW)',
#     'mediaName': '102.2.123.0/30\r\nVRF:YELLOW',
#     'dstDeviceName': 'R3',
#     'outboundInterface': 'Ethernet0/0.15',
#     'nextHopIdList': ['5e30db26-181f-431b-b517-7862e84d7747']},
#    {'hopId': '5e30db26-181f-431b-b517-7862e84d7747',
#     'srcDeviceName': 'R3',
#     'inboundInterface': 'Ethernet0/3',
#     'mediaName': '',
#     'dstDeviceName': 'R20',
#     'outboundInterface': 'Ethernet3/0',
#     'nextHopIdList': ['23115c14-291d-41ee-9fbe-df023f24b667']}],
#   'statusCode': 794008,
#   'statusDescription': "Task '5a977752-cdbc-4ca7-b78f-8c9b9857f3ba' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'e6f8a682-805d-4b0d-b976-efa9440aa6ea' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'e60fbdd3-a028-4cfe-9dea-30c1fd5ebfa6' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'd5340f08-30a0-4029-854d-66f0007ac551' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '3aaa5968-7dfc-4883-ab10-e239ae423f42' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'c942cee0-d6dd-492c-902e-e3f75f7dbe71' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'bdd88f96-de25-4da0-ab37-925c9f7e7e95' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'e6838c8d-4993-407f-92d6-2c4ab6061749' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '91e70b03-2a96-4180-b6b3-2fe4b2f6e6ca' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '2ea0cb2d-3079-480f-9546-253550acea47' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'bb5590bd-5f30-4e8e-a68a-b53d56d4c66d' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '502fba1b-f1de-49d3-97cc-257b96b52363' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '06cab8ed-5410-406d-85e3-488cf16edc54' is failed"},
#  {'hopList': [{'hopId': 'd86c61fb-9441-4701-ac27-24a395667595',
#     'srcDeviceName': 'bar01cntlco',
#     'inboundInterface': 'Bundle-Ether700',
#     'mediaName': '96.34.1.38/31',
#     'dstDeviceName': 'bbr01dnvrco',
#     'outboundInterface': 'Bundle-Ether700',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '2e386b95-28da-4c56-9300-051b7ee76357' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '93683b40-668b-4f17-8f52-c78cd9d64052' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'b80cab17-c7cb-4b01-b1c8-0527f7ed5bb6' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '729229ff-053e-4122-aaa3-6c83768b2868' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '3e3ac527-068d-408c-96a0-d5c37dab44fb' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'e6ab066f-03d1-491b-bca6-1e290ccc1dc4' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '47eb670a-6e49-4ff9-9375-0af08584ed1d' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '739a9f95-3ec4-41e4-af44-8aba74ba3121' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '30316f92-f29e-491e-a149-3f2486cc2226' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'aa56aa68-8b1a-41c3-bf8a-b0582103975d' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'f50941b9-444b-4919-9938-8673752b1a03' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '0d3fc4ad-77fb-4113-9c83-180322d727d3' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'ea2ffc43-228b-4190-94b1-a82bfda96922' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '678aa1d3-4585-4ad5-a69e-07da47c1aa92' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '9420ac2c-afdb-4ccf-9b65-0a2090ac8558' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '7591d008-47f1-4b7f-a4ae-26fd57069b09' is failed"},
#  {'hopList': [{'hopId': '9b7738bd-71ef-4ba7-8582-613c3bd1f545',
#     'srcDeviceName': 'nxs01euclwi',
#     'inboundInterface': 'Ethernet12/32',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01euclwi',
#     'outboundInterface': 'TenGigE0/4/0/2',
#     'nextHopIdList': []},
#    {'hopId': '95f8ad3c-8835-4f40-887e-56293f9a0029',
#     'srcDeviceName': 'nxs01euclwi',
#     'inboundInterface': 'Ethernet13/1',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01euclwi',
#     'outboundInterface': 'TenGigE0/3/0/0',
#     'nextHopIdList': []},
#    {'hopId': 'a9844663-7066-4e18-bcc2-f16599fdb9be',
#     'srcDeviceName': 'nxs01euclwi',
#     'inboundInterface': 'port-channel2',
#     'mediaName': '',
#     'dstDeviceName': '96.34.19.42',
#     'outboundInterface': 'Ethernet0',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'be344329-3f34-4009-8eef-552b3bbb49f8' is failed"},
#  {'hopList': [{'hopId': '92342f04-fd8b-43c1-9b79-bc7f065f0c0f',
#     'srcDeviceName': 'acr01csbyor',
#     'inboundInterface': 'TenGigabitEthernet2/1',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01csbyor',
#     'outboundInterface': 'TenGigE0/4/0/2',
#     'nextHopIdList': []},
#    {'hopId': 'dae538e2-9be3-4bf0-a0e6-fc0daf414ed4',
#     'srcDeviceName': 'acr01csbyor',
#     'inboundInterface': 'TenGigabitEthernet7/3',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01csbyor',
#     'outboundInterface': 'TenGigE0/4/0/1',
#     'nextHopIdList': []},
#    {'hopId': '0391a8f3-c435-4c6b-a416-c7ba72e9f9bc',
#     'srcDeviceName': 'acr01csbyor',
#     'inboundInterface': 'TenGigabitEthernet7/5',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01csbyor',
#     'outboundInterface': 'TenGigE0/3/0/0',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '877bf50a-3628-4fab-952e-4b2d17f42ce1' is failed"},
#  {'hopList': [{'hopId': '8288d935-5313-499a-a2ee-c02167e60a54',
#     'srcDeviceName': 'acr01rsbgor',
#     'inboundInterface': 'TenGigabitEthernet2/5',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01rsbgor',
#     'outboundInterface': 'TenGigE0/0/0/4',
#     'nextHopIdList': []},
#    {'hopId': '801e2eb4-76be-433a-ae1e-2e223262ad9f',
#     'srcDeviceName': 'acr01rsbgor',
#     'inboundInterface': 'TenGigabitEthernet3/8',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01rsbgor',
#     'outboundInterface': 'TenGigE0/0/0/0',
#     'nextHopIdList': []},
#    {'hopId': '9e633ab3-53f2-4312-b98d-f840ba3adf99',
#     'srcDeviceName': 'acr01rsbgor',
#     'inboundInterface': 'TenGigabitEthernet7/4',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01rsbgor',
#     'outboundInterface': 'TenGigE0/0/0/5',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '2dc6de16-52d3-40d1-b5d8-ce2cf87c48a7' is failed"},
#  {'hopList': [{'hopId': 'b3d8a8c8-9669-4a64-8afd-c0c249e5914b',
#     'srcDeviceName': 'acr02lnbhca',
#     'inboundInterface': 'TenGigabitEthernet4/1',
#     'mediaName': 'Bus(acr02lnbhca.TenGigabitEthernet4/1)',
#     'dstDeviceName': '96.34.96.80',
#     'outboundInterface': 'Ethernet0',
#     'nextHopIdList': []},
#    {'hopId': '6f6e12c9-dcbb-4b2d-841f-eb87d993eaa9',
#     'srcDeviceName': 'acr02lnbhca',
#     'inboundInterface': 'TenGigabitEthernet4/5',
#     'mediaName': '',
#     'dstDeviceName': 'dtr02lnbhca',
#     'outboundInterface': 'TenGigE0/0/0/9',
#     'nextHopIdList': []},
#    {'hopId': '2a20f6ec-7bfc-42f1-9daa-09b40ae9b84e',
#     'srcDeviceName': 'acr02lnbhca',
#     'inboundInterface': 'TenGigabitEthernet4/8',
#     'mediaName': '',
#     'dstDeviceName': '96.34.98.52',
#     'outboundInterface': 'Ethernet0',
#     'nextHopIdList': []},
#    {'hopId': 'b831b58f-8f77-4673-9f24-49d8cd3b66a8',
#     'srcDeviceName': 'acr02lnbhca',
#     'inboundInterface': 'TenGigabitEthernet7/3',
#     'mediaName': '',
#     'dstDeviceName': 'dtr02lnbhca',
#     'outboundInterface': 'TenGigE0/0/0/10',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'bc497aeb-0c3c-4dd5-b427-e445ee7f5c4e' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '5629bc93-e21d-4944-b34c-c3c01b9a4151' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '753cb8a2-aabe-4f1b-84a2-abc933b0b2a8' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '389cba14-de02-4531-9385-a66008496770' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '208416f6-a894-41bd-9817-aa62ac3d7491' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '62ec37be-f3d7-4dbe-83a3-bef6b64d1884' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'b797b263-0edf-47c9-8908-e926379e5faa' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'd9fad4d2-678a-4cb1-bb17-7c0cb07685a0' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'd8cde8a7-000f-4654-90a7-0115f5328ebe' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '890c5ce1-019d-4cd2-9007-eae8f84f17da' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'd53f8f97-d274-4e37-8b8c-7ea989eaea22' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '2b4b9ac4-bc49-4c22-8e6c-1750247d043a' is failed"},
#  {'hopList': [{'hopId': '03800c5e-fe9f-428b-82c6-7ee86f12b96d',
#     'srcDeviceName': 'sar01krnyne',
#     'inboundInterface': 'Ethernet1/1',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01krnyne',
#     'outboundInterface': 'TenGigE0/0/0/10',
#     'nextHopIdList': []},
#    {'hopId': 'e057d4c3-4435-4dc0-9c97-b69ed04febb8',
#     'srcDeviceName': 'sar01krnyne',
#     'inboundInterface': 'Ethernet1/2',
#     'mediaName': '',
#     'dstDeviceName': 'dtr01krnyne',
#     'outboundInterface': 'TenGigE0/0/0/12',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'f278616f-a254-4554-b59c-d7d77a4b21ba' is failed"},
#  {'hopList': [{'hopId': 'e744c38b-ca23-4a9d-8c9f-70f6f97d505a',
#     'srcDeviceName': 'sar03euclwi',
#     'inboundInterface': 'Bundle-Ether500',
#     'mediaName': '96.34.2.248/31',
#     'dstDeviceName': 'bbr01euclwi',
#     'outboundInterface': 'Bundle-Ether500',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task 'dfccf77d-3a4d-4a8d-af39-f1a97014cac1' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '9df40ecd-849f-4edf-9eb5-fe62c505a45e' is failed"},
#  {'hopList': [{'hopId': 'a5798930-c67c-4a10-b019-4172d8bc7181',
#     'srcDeviceName': 'chrc1-h01-h01-video-4500-2',
#     'inboundInterface': 'TenGigabitEthernet2/1/30',
#     'mediaName': '',
#     'dstDeviceName': 'chrcnctr01-rtr04',
#     'outboundInterface': 'TenGigE0/8/0/1',
#     'nextHopIdList': ['04d74c61-4cd3-457e-bfb1-989edf18ba72']},
#    {'hopId': '04d74c61-4cd3-457e-bfb1-989edf18ba72',
#     'srcDeviceName': 'chrcnctr01-rtr04',
#     'inboundInterface': 'Bundle-Ether61',
#     'mediaName': '66.109.5.172/31',
#     'dstDeviceName': 'CHRCNCTR04H-BAR03',
#     'outboundInterface': 'Bundle-Ether501',
#     'nextHopIdList': []},
#    {'hopId': '796d294b-4db1-493d-84a3-30743fe1d0ad',
#     'srcDeviceName': 'chrc1-h01-h01-video-4500-2',
#     'inboundInterface': 'TenGigabitEthernet1/1/31',
#     'mediaName': '',
#     'dstDeviceName': 'chrcnctr01-rtr04',
#     'outboundInterface': 'TenGigE0/9/0/1',
#     'nextHopIdList': ['04d74c61-4cd3-457e-bfb1-989edf18ba72']},
#    {'hopId': 'df5edb76-9ad9-46cc-9635-a8e1b89da1e9',
#     'srcDeviceName': 'chrc1-h01-h01-video-4500-2',
#     'inboundInterface': 'TenGigabitEthernet1/1/32',
#     'mediaName': '',
#     'dstDeviceName': 'chrcnctr01-rtr04',
#     'outboundInterface': 'TenGigE1/9/0/1',
#     'nextHopIdList': ['04d74c61-4cd3-457e-bfb1-989edf18ba72']},
#    {'hopId': 'e2b4012b-d823-4a3f-be1c-2f65c28e3132',
#     'srcDeviceName': 'chrc1-h01-h01-video-4500-2',
#     'inboundInterface': 'TenGigabitEthernet2/1/29',
#     'mediaName': '',
#     'dstDeviceName': 'chrcnctr01-rtr04',
#     'outboundInterface': 'TenGigE1/8/0/1',
#     'nextHopIdList': ['04d74c61-4cd3-457e-bfb1-989edf18ba72']},
#    {'hopId': '66b9eb95-a4ce-43d2-937e-2f968952a748',
#     'srcDeviceName': 'chrc1-h01-h01-video-4500-2',
#     'inboundInterface': 'Port-channel3',
#     'mediaName': '',
#     'dstDeviceName': '71.66.60.100',
#     'outboundInterface': 'Ethernet0',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '8ac33e87-fe47-44ca-be7c-580639bb58ca' is failed"},
#  {'hopList': [{'hopId': '6a6ed0f3-2bd2-4dfa-8136-0c880f0cb143',
#     'srcDeviceName': 'chrcnctr01-rtr04',
#     'inboundInterface': '',
#     'mediaName': '',
#     'dstDeviceName': 'CHRCNCTR04H-BAR03',
#     'outboundInterface': '',
#     'nextHopIdList': []}],
#   'statusCode': 794008,
#   'statusDescription': "Task '2d78f1be-4bd4-4bce-8bf7-13969590f44c' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '39154a68-eaf3-4495-b74e-8d609f19f10e' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'b705d24c-1a09-4102-8239-0996898f3c6d' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'bff91857-c97f-4867-9124-bdc57453849d' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task 'f1da66e3-bd45-4ad2-a211-e6075e3cd46e' is failed"},
#  {'hopList': [],
#   'statusCode': 794008,
#   'statusDescription': "Task '476955e0-0d92-4732-a806-e31249d1b403' is failed"}]

# %% [markdown]
# From the final result, we can see all tasks are failed, that is because in Step 8 we couple the gateway addresses randomly, which means that is possible for each pair of the gateways, there is no through path between them. And as a clarification, if users get the taskId from Step 8 successfully, that is not means the path is exist during gateway pairs.

# %% [markdown]
# ## Step 10: Calling Logout API
# After we got all informations from this case, we have to logout from the Netbrain System.
# If users want to get more details about this API or get errors when calling this API please check the API documentation on [Github_logout](https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_Logout_Test1%20.ipynb).

# %%
Logout_url = nb_url + "/ServicesAPI/API/V1/Session"

def logout(Logout_url, token, headers):
    headers["token"] = token
    
    try:
        # Do the HTTP request
        response = requests.delete(Logout_url, headers=headers, verify=False)
        # Check for HTTP codes other than 200
        if response.status_code == 200:
            # Decode the JSON response into a dictionary and use the data
            js = response.json()
            return (js)
        else:
            return ("Session logout failed! - " + str(response.text))

    except Exception as e:
        return (str(e))

logout = logout(Logout_url, token, headers)
logout

# %% [markdown]
# ## References:
# > 1) login API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_TEST1_LOGIN_API.ipynb<br>
# > 2) get_all_accessible_tenants API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_TEST1_Get_All_Asseccible_Tenants_API_Test1%20.ipynb<br>
# > 3) get_all_accessible_domains API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_Get_all_accessible_domains_of_a_tenant%20_Test1%20.ipynb<br>
# > 4) specify_a_working_domain API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_Specify_a_domain_to_work_on_API_Test1%20.ipynb<br>
# > 5) get_all_devices API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Device%20API%20Design/STANDARD_formate_Get_Devices_API_Test.ipynb<br>
# > 6) get_one_ip_table API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Overall%20Plan%EF%BC%88Northbound%20API%EF%BC%89/STANDARD_formate_GEt_One_Ip_Table_API_Test1%20.ipynb<br>
# > 7) resolve_device_gateway API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Path%20API%20Design/STANDARD_formate_Resolve_Device_Gateway_API_Test.ipynb<br>
# > 8) calculate_path API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Path%20API%20Design/STANDARD_formate_Calculate_Path_API_Test.ipynb<br>
# > 9) get_patth_result API: https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/Path%20API%20Design/STANDARD_formate_Get_Path_Calculation_Result_API_Test.ipynb
# > 10) logout API:
# https://github.com/Gongdai/Netbrain_REST_API_First_Regularization/blob/master/Netbrain_REST_API/API_test/STANDARD_formate_Logout_Test1%20.ipynb
