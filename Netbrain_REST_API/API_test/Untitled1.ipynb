# %% [markdown]
# # Authentication and Initialization API STANDARD Formate TEST1
# OpenAPI version 1.0.0
#
# * ## Path
# ### **POST**/V1/Session/{body}/{nb_url}
#
# > **Description**: This method creates an authentication token and starts a session with user's body information and netbrain server url.
#
# * ## Authentication Not Required
#
# * ## Info
#
# > **title** : Log in API<br>
#
# > **version** : 01/22/2019.
#
# * ## API Servers
#
# > **URL** : http(s):// IP address of your NetBrain Web API Server/ServicesAPI/API/V1/Session
#
# * ## Request body(*required)
#
# > |**Name**|**Type**|**Description**|
# |------|------|------|
# |username* | string  | the username to log into your NetBrain domain.  |
# |password* | string  | the password to log into your NetBrain domain.  |
# |authentication_id | string  | The authentication ID of an external user through SSO, LDAP/AD or TACACS. This parameter is only required for an external user and the value is alias. |
#
# > ***Example*** :

# %% [markdown]
# # Basic Structure
# OpenAPI version (like 3.0.0)<br><br>
# * ## Info
#
# > **title** : API name<br>
#
# > **Description**: extend information.<br>
#
# >> **CommonMark**: Http:// help/...
#
# > **version**: an arbitrary string, like major.minor.patch, 1.0-beta or 2017-07-25.
#
# <br><br>
# * ## Servers
#
# > **URL**: like: http://api.example.com/v1/users
#
# <br><br>
# * ## Path
# ### **GET**.../a part of URL/Inputs
#
# > **Summary**: optional
#
# > **Description**: optional
#
# <br><br>
# * ## Parameters / Request body(for POST, PUT method)
# > same as before
#
# <br><br>
# * ## Response
#
# > **Status Code**:
#
# > |**Name**|**Message**|**Details**|
# |------|------|------|
# | 200 | Success  | Success with response body.  |
#
# > **responses information**:<br>
# > same as before
#
# <br><br>
# * ## Authentication
#
# >|**Type**|**In**|**Name**|
# |------|------|------|
# |Bearer Auth| Header | Name |
